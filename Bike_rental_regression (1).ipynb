# %% [markdown]
# # **Bike-Sharing Rental**

# %% [markdown]
# #**Problem Statement :**
# The business problem is to ensure a stable supply of rental bikes in urban cities by predicting the demand for bikes.By providing a stable supply of rental bikes, the system can enhance mobility comfort for the public and reduce waiting time,leading to greater customer satisfaction and accurately predicting bike demand can help bike sharing companies optimize operations including bike availability,pricing,strategies,and marketing efforts by considering demand Based on various external factors such as weather,season,holiday etc..,
#
# ## **1.Exploratory Data Analysis (EDA):**
# •Describe the dataset: Understand the structure, columns, and data types.
# •Clean the data: Check for invalid records, missing values, duplicated records, and outliers.
# •Handle missing values: Detect missing values and apply appropriate imputation techniques.
# •Detect outliers: Identify outliers and decide whether to remove or transform them.
#
# ## **2.Data Visualization:**
# •Creating visualizations such as scatter plots, line plots, and bar plots to explore relationships between variables.
# •Plotting time series data to analyze trends and seasonality.
# •Using heatmaps or correlation matrices to understand the correlation between different features.
# •Utilizing seaborn, matplotlib, or other libraries for generating informative and visually appealing plots.
#
# ##**3.Feature Engineering:**
# •Generating new features from existing ones to improve model performance.
# •Handling categorical variables through techniques like one-hot encoding or label encoding.
# •Scaling or normalizing numerical features to ensure uniformity in their ranges.
# •Incorporating domain knowledge to create meaningful features that capture important aspects of the data.
#
# ##**4.Model Building:**
# •	Selecting appropriate machine learning algorithms such as Decision Tree, Random Forest, and Gradient Boosting Regression for predicting bike rental demand.
# •Splitting the dataset into training and testing sets for model evaluation.
# •Training various models using the training data and evaluating their performance using metrics like RMSE, MAE, or R-squared.
# •Fine-tuning model parameters to optimize performance.
#
# ##**5.Hyperparameter Tuning:**
# •Conducting hyperparameter tuning for Decision Tree,Random Forest,and Gradient Boosting Regression using techniques like grid search or random search to find the best combination of model parameters.
# •Evaluating model performance with different hyperparameter values using cross-validation techniques.
# •Balancing model complexity and performance to prevent overfitting or underfitting.
#
# ##**6.Model Evaluation:**
# •Evaluation metrics for regression models: Mean Absolute Error (MAE), Mean Squared Error (MSE), Root Mean Squared Error (RMSE), R-squared (R^2), etc.
# •Compare the performance of different models to select the best one.
#
# ##**7.Model Deployment:**
# •Once the best model is selected, deploy it in a production environment where it can be used to make predictions.
# •Monitor the performance of the deployed model over time and update it as needed.

# %% [markdown]
# ##Dataset Dictionary:
# 1.Instant: Index number
# 2.Dteday: Date(Format: YYYY-MM-DD)
# 3.Season: Season Name
# 4.Yr: Year
# 5.Month: Month(1-12)(Jan-Dec)
# 6.Hr: Hour(0 to 23)
# 7.Holiday: Whether the holiday is there or not
# 8.Weekday: Day of the week
# 9.Workingday: Whether it is a working day or not
# 10.Weathersit: Weather situation
# 11.Temp: Normalized temperature in Celsius
# 12.Atemp: Normalized feeling temperature
# 13.Hum: Normalized humidity. The Values are divided by 100
# 14.Windspeed: Normalized Wind speed. Values are divided by 67
# 15.Casual: Count of casual users
# 16.Registered: Number of registered users
# 17.Cnt: Count of total rental biked including both casual and registered

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns

# %%
bike_df=pd.read_csv('/content/bike_rent (1) (1).csv',index_col='instant')

# %%
bike_df
# Out:
#              dteday    season    yr mnth  hr holiday  weekday   workingday  \
# instant
# 1        01-01-2011  springer  2011    1   0      No        6      No work
# 2        01-01-2011  springer  2011    1   1      No        6      No work
# 3        01-01-2011  springer  2011    1   2      No        6      No work
# 4        01-01-2011  springer  2011    1   3      No        6      No work
# 5        01-01-2011  springer  2011    1   4      No        6      No work
# ...             ...       ...   ...  ...  ..     ...      ...          ...
# 17375    31-12-2012  springer  2012   12  19      No        1  Working Day
# 17376    31-12-2012  springer  2012   12  20      No        1  Working Day
# 17377    31-12-2012  springer  2012   12  21      No        1  Working Day
# 17378    31-12-2012  springer  2012   12  22      No        1  Working Day
# 17379    31-12-2012  springer  2012   12  23      No        1            ?
#
#         weathersit  temp   atemp   hum windspeed casual registered  cnt
# instant
# 1            Clear  0.24  0.2879  0.81         0      3         13   16
# 2            Clear  0.22  0.2727   0.8         0      8         32   40
# 3            Clear  0.22  0.2727     ?         0      5         27   32
# 4            Clear  0.24  0.2879  0.75         0      3         10   13
# 5            Clear  0.24  0.2879  0.75         0      0          1    1
# ...            ...   ...     ...   ...       ...    ...        ...  ...
# 17375         Mist  0.26  0.2576   0.6    0.1642     11        108  119
# 17376         Mist  0.26  0.2576   0.6    0.1642      8         81   89
# 17377        Clear     ?  0.2576   0.6    0.1642      7         83   90
# 17378        Clear  0.26  0.2727  0.56    0.1343     13         48   61
# 17379        Clear  0.26  0.2727  0.65    0.1343     12         37   49
#
# [17379 rows x 16 columns]

# %% [markdown]
# # **1.	Exploratory Data Analysis (EDA):**

# %% [markdown]
# ###Describe the dataset: Understand the structure, columns, and data types.

# %%
bike_df.head()
# Out:
#              dteday    season    yr mnth  hr holiday  weekday workingday  \
# instant
# 1        01-01-2011  springer  2011    1   0      No        6    No work
# 2        01-01-2011  springer  2011    1   1      No        6    No work
# 3        01-01-2011  springer  2011    1   2      No        6    No work
# 4        01-01-2011  springer  2011    1   3      No        6    No work
# 5        01-01-2011  springer  2011    1   4      No        6    No work
#
#         weathersit  temp   atemp   hum windspeed casual registered  cnt
# instant
# 1            Clear  0.24  0.2879  0.81         0      3         13   16
# 2            Clear  0.22  0.2727   0.8         0      8         32   40
# 3            Clear  0.22  0.2727     ?         0      5         27   32
# 4            Clear  0.24  0.2879  0.75         0      3         10   13
# 5            Clear  0.24  0.2879  0.75         0      0          1    1

# %%
bike_df.tail()
# Out:
#              dteday    season    yr mnth  hr holiday  weekday   workingday  \
# instant
# 17375    31-12-2012  springer  2012   12  19      No        1  Working Day
# 17376    31-12-2012  springer  2012   12  20      No        1  Working Day
# 17377    31-12-2012  springer  2012   12  21      No        1  Working Day
# 17378    31-12-2012  springer  2012   12  22      No        1  Working Day
# 17379    31-12-2012  springer  2012   12  23      No        1            ?
#
#         weathersit  temp   atemp   hum windspeed casual registered  cnt
# instant
# 17375         Mist  0.26  0.2576   0.6    0.1642     11        108  119
# 17376         Mist  0.26  0.2576   0.6    0.1642      8         81   89
# 17377        Clear     ?  0.2576   0.6    0.1642      7         83   90
# 17378        Clear  0.26  0.2727  0.56    0.1343     13         48   61
# 17379        Clear  0.26  0.2727  0.65    0.1343     12         37   49

# %%
#Structure
bike_df.shape
# Out:
# (17379, 16)

# %%
#Check for unique values
bike_df.nunique()
# Out:
# dteday        731
# season          5
# yr              3
# mnth           13
# hr             24
# holiday         3
# weekday         7
# workingday      3
# weathersit      5
# temp           51
# atemp          66
# hum            90
# windspeed      31
# casual        323
# registered    777
# cnt           869
# dtype: int64

# %%
bike_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17379 entries, 1 to 17379
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   dteday      17379 non-null  object
#  1   season      17379 non-null  object
#  2   yr          17379 non-null  object
#  3   mnth        17379 non-null  object
#  4   hr          17379 non-null  int64
#  5   holiday     17379 non-null  object
#  6   weekday     17379 non-null  int64
#  7   workingday  17379 non-null  object
#  8   weathersit  17379 non-null  object
#  9   temp        17379 non-null  object
#  10  atemp       17379 non-null  object
#  11  hum         17379 non-null  object
#  12  windspeed   17379 non-null  object
#  13  casual      17379 non-null  object
#  14  registered  17379 non-null  object
#  15  cnt         17379 non-null  int64
# dtypes: int64(3), object(13)
# memory usage: 2.3+ MB

# %%
#Datatypes
bike_df.dtypes
# Out:
# dteday        object
# season        object
# yr            object
# mnth          object
# hr             int64
# holiday       object
# weekday        int64
# workingday    object
# weathersit    object
# temp          object
# atemp         object
# hum           object
# windspeed     object
# casual        object
# registered    object
# cnt            int64
# dtype: object

# %%
categorical_columns=bike_df.select_dtypes(include='object').columns
categorical_columns
# Out:
# Index(['dteday', 'season', 'yr', 'mnth', 'holiday', 'workingday', 'weathersit',
#        'temp', 'atemp', 'hum', 'windspeed', 'casual', 'registered'],
#       dtype='object')

# %%
numerical_columns=bike_df.select_dtypes(include=np.number).columns
numerical_columns
# Out:
# Index(['hr', 'weekday', 'cnt'], dtype='object')

# %%
bike_df.describe()
# Out:
#                  hr       weekday           cnt
# count  17379.000000  17379.000000  17379.000000
# mean      11.546752      3.003683    189.463088
# std        6.914405      2.005771    181.387599
# min        0.000000      0.000000      1.000000
# 25%        6.000000      1.000000     40.000000
# 50%       12.000000      3.000000    142.000000
# 75%       18.000000      5.000000    281.000000
# max       23.000000      6.000000    977.000000

# %% [markdown]
# ###Clean the data: Check for invalid records, missing values, duplicated records, and outliers.

# %%
#Check for invalid records
invalid_records=bike_df.isin(['?','-','N/A','None','']).sum()
invalid_records
# Out:
# dteday         0
# season         6
# yr             1
# mnth           1
# hr             0
# holiday        1
# weekday        0
# workingday     5
# weathersit     4
# temp          11
# atemp          6
# hum            6
# windspeed      5
# casual         1
# registered     1
# cnt            0
# dtype: int64

# %%
#Replace invalid records with NAN
bike_df.replace(['?','-','N/A','None',''],np.nan,inplace=True)

# %%
#Check for missing values
bike_df.isnull().sum()
# Out:
# dteday         0
# season         6
# yr             1
# mnth           1
# hr             0
# holiday        1
# weekday        0
# workingday     5
# weathersit     4
# temp          11
# atemp          6
# hum            6
# windspeed      5
# casual         1
# registered     1
# cnt            0
# dtype: int64

# %%
#Check for Duplicated Records
bike_df.duplicated().sum()
# Out:
# 0

# %%
#No Duplicates Found

# %%
#Check for Outliers
numerical_columns = ['yr','mnth','hr','weekday','temp', 'atemp', 'hum', 'windspeed', 'casual', 'registered', 'cnt']

# %%
#Convert specified columns to numeric, handling errors by coercing them to NaN
for column in ['temp', 'atemp', 'hum', 'windspeed', 'casual', 'registered', 'cnt']:
    bike_df[column] = pd.to_numeric(bike_df[column], errors='coerce')

# Redefine numerical_columns to ensure it only contains numeric columns
numerical_columns = bike_df.select_dtypes(include=np.number).columns

def detect_outliers_iqr(data, column):
    Q1 = bike_df[column].quantile(0.25)
    Q3 = bike_df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers_indices = ((bike_df[column] < (lower_bound)) | (bike_df[column] > (upper_bound))).sum()
    return outliers_indices

for col in numerical_columns:
    outliers_indices=detect_outliers_iqr(bike_df,col)
    print(f"Number of outliers in {col}: {outliers_indices}")
# Out:
# Number of outliers in hr: 0
# Number of outliers in weekday: 0
# Number of outliers in temp: 0
# Number of outliers in atemp: 0
# Number of outliers in hum: 22
# Number of outliers in windspeed: 341
# Number of outliers in casual: 1192
# Number of outliers in registered: 680
# Number of outliers in cnt: 505

# %% [markdown]
# ###Handle missing values: Detect missing values and apply appropriate imputation techniques.

# %%
#Check for any missing values(Before)
bike_df.isnull().sum()
# Out:
# dteday         0
# season         6
# yr             1
# mnth           1
# hr             0
# holiday        1
# weekday        0
# workingday     5
# weathersit     4
# temp          11
# atemp          6
# hum            6
# windspeed      5
# casual         1
# registered     1
# cnt            0
# dtype: int64

# %%
#Handle missing values for both Numerical(mean) and Categorical columns(mode)
for col in bike_df.columns:
    if bike_df[col].isnull().sum() > 0:  # Check if the column has missing values
        if bike_df[col].dtype in ['float64', 'int64']:  #For Numeric column
            bike_df[col].fillna(bike_df[col].mean(), inplace=True)
        else:  #For Categorical column
            bike_df[col].fillna(bike_df[col].mode()[0], inplace=True)

# %%
#Check for any missing values(After)
bike_df.isnull().sum()
# Out:
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %% [markdown]
# ###Detect outliers: Identify outliers and decide whether to remove or transform them.

# %%
# Select numerical columns
numerical_columns = ['temp', 'atemp', 'hum', 'windspeed', 'casual', 'registered', 'cnt']

# %%
for col in numerical_columns:
    Q1 = bike_df[col].quantile(0.25)
    Q3 = bike_df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

# %%
#Identify Outliers
outliers = bike_df[(bike_df[col] < lower_bound) | (bike_df[col] > upper_bound)]
outliers
# Out:
#              dteday    season    yr mnth  hr holiday  weekday   workingday  \
# instant
# 5537     23-08-2011      fall  2011    8  14      No        2  Working Day
# 10359    12-03-2012  springer  2012    3  17      No        1  Working Day
# 10360    12-03-2012  springer  2012    3  18      No        1  Working Day
# 10383    13-03-2012  springer  2012    3  17      No        2  Working Day
# 10384    13-03-2012  springer  2012    3  18      No        2  Working Day
# ...             ...       ...   ...  ...  ..     ...      ...          ...
# 16886    11-12-2012    winter  2012   12   8      No        2  Working Day
# 16910    12-12-2012    winter  2012   12   8      No        3  Working Day
# 16934    13-12-2012    winter  2012   12   8      No        4  Working Day
# 17054    18-12-2012    winter  2012   12   8      No        2  Working Day
# 17078    19-12-2012    winter  2012   12   8      No        3  Working Day
#
#         weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# instant
# 5537         Clear  0.72  0.6515  0.30     0.0896   149.0       502.0  651
# 10359         Mist  0.62  0.6212  0.38     0.4179    87.0       557.0  644
# 10360         Mist  0.60  0.6212  0.43     0.1940    89.0       623.0  712
# 10383        Clear  0.70  0.6364  0.37     0.1045    62.0       614.0  676
# 10384        Clear  0.70  0.6364  0.34     0.2985    96.0       638.0  734
# ...            ...   ...     ...   ...        ...     ...         ...  ...
# 16886         Mist  0.34  0.3030  0.61     0.2985    16.0       708.0  724
# 16910         Mist  0.26  0.2576  0.65     0.1642    18.0       670.0  688
# 16934        Clear  0.24  0.2273  0.60     0.1940    24.0       655.0  679
# 17054        Clear  0.38  0.3939  0.94     0.0000    10.0       652.0  662
# 17078        Clear  0.24  0.2576  0.87     0.1045    13.0       665.0  678
#
# [505 rows x 16 columns]

# %%
#First method:Remove Outliers
bike_df=bike_df[(bike_df[col] >= lower_bound) & (bike_df[col] <= upper_bound)]

# %%
#Second method:Cap Outliers(transform)
bike_df[col]=np.clip(bike_df[col],lower_bound,upper_bound)

# %% [markdown]
# # **2.Data Visualization:**

# %% [markdown]
# ###Creating visualizations such as scatter plots, line plots, and bar plots to explore relationships between variables.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#SCATTER PLOT
#Temperature vs Bike Rentals:
plt.figure(figsize=(8,6))
sns.scatterplot(x='temp', y='cnt', data=bike_df)
plt.title('Temperature vs. Bike Rentals')
plt.xlabel('Temperature')
plt.ylabel('Bike Rentals')
plt.show()

# %%
#Key Insight in Temperature vs Bike Rentals
#Rentals increase with moderate temperatures,peaking at an ideal range(e.g., 20–30°C) and Extremely high or low temperatures reduce rentals due to user discomfort.

# %%
#Humidity vs Bike Rentals:
plt.figure(figsize=(8,6))
sns.scatterplot(x='hum', y='cnt', data=bike_df)
plt.title('Humidity vs. Bike Rentals')
plt.xlabel('Humidity')
plt.ylabel('Bike Rentals')
plt.show()

# %%
#Key Insight in Humidity vs Bike Rentals
#Higher humidity (above 80%) might negatively affect bike rentals.Mostly Moderate humidity levels (40–70%) may correlate with higher rentals as conditions are more comfortable.

# %%
#Windspeed vs Bike Rentals:
plt.figure(figsize=(8,6))
sns.scatterplot(x='windspeed', y='cnt', data=bike_df)
plt.title('Windspeed vs. Bike Rentals')
plt.xlabel('Windspeed')
plt.ylabel('Bike Rentals')
plt.show()

# %%
#Key Insights in Windspeed vs Bike Rentals
#Rentals decline as windspeed increases,especially above a certain threshold(e.g.,>20 km/h),due to challenging riding conditions and Lower wind speeds are more favorable for bike users.

# %%
#Hour vs Rentals
plt.figure(figsize=(8,6))
sns.barplot(x='hr', y='cnt', data=bike_df)
plt.title('Hour vs. Rentals')
plt.xlabel('Hour')
plt.ylabel('Rentals')
plt.show()

# %%
#Key Insights in
#Rentals spike during commute hours (8–10 AM,5–7 PM) on working days.In Non-working days it peaks in the afternoon (12 PM–3 PM), likely due to leisure activities.

# %%
#LINE PLOT
#Bike Rentals Over Time:
plt.figure(figsize=(8,6))
sns.lineplot(x='dteday',y='cnt',data=bike_df)
plt.title('Daily Bike Rentals Trend')
plt.xlabel('Date')
plt.ylabel('Total Bike Rentals')
plt.xticks(rotation=45)
plt.show()

# %%
#Key Insights
#Rentals may show an increasing trend over time due to the growing popularity of the service.
#Clear seasonality: higher rentals in spring/summer and lower in winter.

# %%
#Hourly Rentals by Working Day:
plt.figure(figsize=(8,6))
sns.lineplot(x='hr', y='cnt',hue='workingday',data=bike_df)
plt.title('Hourly Rentals by Working Day')
plt.xlabel('Hour')
plt.ylabel('Total Bike Rentals')
plt.show()

# %%
#Key Insights
#On Working Days: Rentals spike during commute hours (8–10 AM, 5–7 PM).
#On Non-Working Days: Peak usage during leisure hours (12–3 PM).

# %%
#Hourly Rentals by Season
plt.figure(figsize=(8,6))
sns.lineplot(x='hr', y='cnt',hue='season',data=bike_df)
plt.title('Hourly Rentals by Season')
plt.xlabel('Hour')
plt.ylabel('Total Bike Rentals')
plt.show()

# %%
#Key Insight:
#In Spring/Summer: Higher overall rentals with mid-day peaks.
#In Winter/Fall: Lower rentals throughout the day, indicating seasonal weather impacts.

# %%
#BAR PLOT
#Average Rentals by Season:
plt.figure(figsize=(8,6))
sns.barplot(x='season', y='cnt', data=bike_df)
plt.title('Average Rentals by Season')
plt.xlabel('Season')
plt.ylabel('Average Rentals')
plt.show()

# %%
#KEY INSIGHTS
#Spring and summer have higher bike rentals due to favorable weather where as winter shows the lowest rentals due to harsh weather conditions.

# %%
#Rentals by Weather Condition
plt.figure(figsize=(8,6))
sns.barplot(x='weathersit', y='cnt', data=bike_df)
plt.title('Rentals by Weather Condition')
plt.xlabel('Weather Condition')
plt.ylabel('Total Rentals')
plt.show()

# %%
#Key Insight:
#Clear weather leads to significantly higher rentals and Poor weather(e.g.,rain,snow) results in fewer rentals.

# %%
#Bike Rentals on Holidays:
plt.figure(figsize=(8,6))
sns.barplot(x='holiday', y='cnt', data=bike_df)
plt.title('Bike Rentals on Holidays')
plt.xlabel('Holiday')
plt.ylabel('Total Rentals')
plt.show()

# %%
#Key Insight:
#Rentals are slightly lower on holidays, as fewer people commute and Casual rentals may increase depending on the holiday type.

# %%
#Bike Rentals by Month
plt.figure(figsize=(8,6))
sns.barplot(x='mnth', y='cnt', data=bike_df)
plt.title('Bike Rentals by Month')
plt.xlabel('Month')
plt.ylabel('Total Rentals')
plt.show()

# %%
#Key Insight:
#Rentals peak during warmer months (e.g., May–August) and Cold months(e.g.,December–February) show a drop in bike usage.

# %% [markdown]
# ###Plotting time series data to analyze trends and seasonality.

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
##converting the dtetime column into datetime format and setting it as index
bike_df_dup=bike_df.copy()
bike_df_dup['dteday'] = pd.to_datetime(bike_df_dup['dteday'],format='mixed')
bike_df_dup.set_index('dteday', inplace=True)
print(bike_df_dup.head())
# Out:
#               season    yr mnth  hr holiday  weekday workingday weathersit  \
# dteday
# 2011-01-01  springer  2011    1   0      No        6    No work      Clear
# 2011-01-01  springer  2011    1   1      No        6    No work      Clear
# 2011-01-01  springer  2011    1   2      No        6    No work      Clear
# 2011-01-01  springer  2011    1   3      No        6    No work      Clear
# 2011-01-01  springer  2011    1   4      No        6    No work      Clear
#
#             temp   atemp       hum  windspeed  casual  registered  cnt
# dteday
# 2011-01-01  0.24  0.2879  0.810000        0.0     3.0        13.0   16
# 2011-01-01  0.22  0.2727  0.800000        0.0     8.0        32.0   40
# 2011-01-01  0.22  0.2727  0.627208        0.0     5.0        27.0   32
# 2011-01-01  0.24  0.2879  0.750000        0.0     3.0        10.0   13
# 2011-01-01  0.24  0.2879  0.750000        0.0     0.0         1.0    1

# %%
plt.figure(figsize=(12, 6))
plt.plot(bike_df.index, bike_df['cnt'], label='Daily Rentals', color='blue')
plt.title('Daily Bike Rentals Over Time')
plt.xlabel('Date')
plt.ylabel('Total Rentals')
plt.legend()
plt.grid()
plt.show()

# %%
decompose_result = seasonal_decompose(bike_df['cnt'], model='additive', period=365)

# %%
decompose_result.seasonal.plot()
# Out:
# <Axes: xlabel='instant'>

# %%
decompose_result.trend.plot()
# Out:
# <Axes: xlabel='instant'>

# %%
decompose_result.resid.plot()
# Out:
# <Axes: xlabel='instant'>

# %% [markdown]
# Trend: Rentals show a clear upward trend, reflecting increased popularity.
#
# Seasonality: Rentals are higher in summer and lower in winter, following annual weather patterns.
#
# Residuals: Spikes or dips could indicate outlier events like weather disruptions or holidays.

# %% [markdown]
# **Key Insights:**
#
# 1)Rentals peak during summer months (May–August) and decline in winter months (December–February).
#
# 2)higher rentals on weekends for leisure and higher on weekdays during leisure hours.
#
# 3)Rentals are time-sensitive, with peaks during specific hours on working and non-working days.

# %% [markdown]
# ### Using heatmaps or correlation matrices to understand the correlation between different features.

# %%
bike_df
# Out:
#              dteday    season    yr mnth  hr holiday  weekday   workingday  \
# instant
# 1        01-01-2011  springer  2011    1   0      No        6      No work
# 2        01-01-2011  springer  2011    1   1      No        6      No work
# 3        01-01-2011  springer  2011    1   2      No        6      No work
# 4        01-01-2011  springer  2011    1   3      No        6      No work
# 5        01-01-2011  springer  2011    1   4      No        6      No work
# ...             ...       ...   ...  ...  ..     ...      ...          ...
# 17375    31-12-2012  springer  2012   12  19      No        1  Working Day
# 17376    31-12-2012  springer  2012   12  20      No        1  Working Day
# 17377    31-12-2012  springer  2012   12  21      No        1  Working Day
# 17378    31-12-2012  springer  2012   12  22      No        1  Working Day
# 17379    31-12-2012  springer  2012   12  23      No        1  Working Day
#
#         weathersit      temp   atemp       hum  windspeed  casual  registered  \
# instant
# 1            Clear  0.240000  0.2879  0.810000     0.0000     3.0        13.0
# 2            Clear  0.220000  0.2727  0.800000     0.0000     8.0        32.0
# 3            Clear  0.220000  0.2727  0.627208     0.0000     5.0        27.0
# 4            Clear  0.240000  0.2879  0.750000     0.0000     3.0        10.0
# 5            Clear  0.240000  0.2879  0.750000     0.0000     0.0         1.0
# ...            ...       ...     ...       ...        ...     ...         ...
# 17375         Mist  0.260000  0.2576  0.600000     0.1642    11.0       108.0
# 17376         Mist  0.260000  0.2576  0.600000     0.1642     8.0        81.0
# 17377        Clear  0.497132  0.2576  0.600000     0.1642     7.0        83.0
# 17378        Clear  0.260000  0.2727  0.560000     0.1343    13.0        48.0
# 17379        Clear  0.260000  0.2727  0.650000     0.1343    12.0        37.0
#
#          cnt
# instant
# 1         16
# 2         40
# 3         32
# 4         13
# 5          1
# ...      ...
# 17375    119
# 17376     89
# 17377     90
# 17378     61
# 17379     49
#
# [16874 rows x 16 columns]

# %%
bike_df[numerical_columns].corr()
# Out:
#                 temp     atemp       hum  windspeed    casual  registered  \
# temp        1.000000  0.987622 -0.054623  -0.028308  0.463952    0.324552
# atemp       0.987622  1.000000 -0.037289  -0.068357  0.457874    0.323126
# hum        -0.054623 -0.037289  1.000000  -0.288847 -0.333341   -0.280581
# windspeed  -0.028308 -0.068357 -0.288847   1.000000  0.085016    0.089437
# casual      0.463952  0.457874 -0.333341   0.085016  1.000000    0.521634
# registered  0.324552  0.323126 -0.280581   0.089437  0.521634    1.000000
# cnt         0.401278  0.398314 -0.326868   0.097894  0.720218    0.967558
#
#                  cnt
# temp        0.401278
# atemp       0.398314
# hum        -0.326868
# windspeed   0.097894
# casual      0.720218
# registered  0.967558
# cnt         1.000000

# %%
sns.heatmap(bike_df[numerical_columns].corr(),annot=True,cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# Insights:
#
# 1)Temperature and atmospheric temperature has highest positive correlation(multi collinearity)
#
# 2)Registered and cnt temperature has highest positive correlation(multi collinearity)

# %% [markdown]
# # **3.Feature Engineering:**

# %% [markdown]
# ### Generating new features from existing ones to improve model performance.

# %%
bike_df
# Out:
#              dteday    season    yr mnth  hr holiday  weekday   workingday  \
# instant
# 1        01-01-2011  springer  2011    1   0      No        6      No work
# 2        01-01-2011  springer  2011    1   1      No        6      No work
# 3        01-01-2011  springer  2011    1   2      No        6      No work
# 4        01-01-2011  springer  2011    1   3      No        6      No work
# 5        01-01-2011  springer  2011    1   4      No        6      No work
# ...             ...       ...   ...  ...  ..     ...      ...          ...
# 17375    31-12-2012  springer  2012   12  19      No        1  Working Day
# 17376    31-12-2012  springer  2012   12  20      No        1  Working Day
# 17377    31-12-2012  springer  2012   12  21      No        1  Working Day
# 17378    31-12-2012  springer  2012   12  22      No        1  Working Day
# 17379    31-12-2012  springer  2012   12  23      No        1  Working Day
#
#         weathersit      temp   atemp       hum  windspeed  casual  registered  \
# instant
# 1            Clear  0.240000  0.2879  0.810000     0.0000     3.0        13.0
# 2            Clear  0.220000  0.2727  0.800000     0.0000     8.0        32.0
# 3            Clear  0.220000  0.2727  0.627208     0.0000     5.0        27.0
# 4            Clear  0.240000  0.2879  0.750000     0.0000     3.0        10.0
# 5            Clear  0.240000  0.2879  0.750000     0.0000     0.0         1.0
# ...            ...       ...     ...       ...        ...     ...         ...
# 17375         Mist  0.260000  0.2576  0.600000     0.1642    11.0       108.0
# 17376         Mist  0.260000  0.2576  0.600000     0.1642     8.0        81.0
# 17377        Clear  0.497132  0.2576  0.600000     0.1642     7.0        83.0
# 17378        Clear  0.260000  0.2727  0.560000     0.1343    13.0        48.0
# 17379        Clear  0.260000  0.2727  0.650000     0.1343    12.0        37.0
#
#          cnt
# instant
# 1         16
# 2         40
# 3         32
# 4         13
# 5          1
# ...      ...
# 17375    119
# 17376     89
# 17377     90
# 17378     61
# 17379     49
#
# [16874 rows x 16 columns]

# %%
bike_df['dteday'] = pd.to_datetime(bike_df['dteday'],format='mixed')

# %%
bike_df['dteday'] = bike_df['dteday'] + pd.to_timedelta(bike_df['hr'], unit='h')

# %%
bike_df
# Out:
#                      dteday    season    yr mnth  hr holiday  weekday  \
# instant
# 1       2011-01-01 00:00:00  springer  2011    1   0      No        6
# 2       2011-01-01 01:00:00  springer  2011    1   1      No        6
# 3       2011-01-01 02:00:00  springer  2011    1   2      No        6
# 4       2011-01-01 03:00:00  springer  2011    1   3      No        6
# 5       2011-01-01 04:00:00  springer  2011    1   4      No        6
# ...                     ...       ...   ...  ...  ..     ...      ...
# 17375   2012-12-31 19:00:00  springer  2012   12  19      No        1
# 17376   2012-12-31 20:00:00  springer  2012   12  20      No        1
# 17377   2012-12-31 21:00:00  springer  2012   12  21      No        1
# 17378   2012-12-31 22:00:00  springer  2012   12  22      No        1
# 17379   2012-12-31 23:00:00  springer  2012   12  23      No        1
#
#           workingday weathersit      temp   atemp       hum  windspeed  \
# instant
# 1            No work      Clear  0.240000  0.2879  0.810000     0.0000
# 2            No work      Clear  0.220000  0.2727  0.800000     0.0000
# 3            No work      Clear  0.220000  0.2727  0.627208     0.0000
# 4            No work      Clear  0.240000  0.2879  0.750000     0.0000
# 5            No work      Clear  0.240000  0.2879  0.750000     0.0000
# ...              ...        ...       ...     ...       ...        ...
# 17375    Working Day       Mist  0.260000  0.2576  0.600000     0.1642
# 17376    Working Day       Mist  0.260000  0.2576  0.600000     0.1642
# 17377    Working Day      Clear  0.497132  0.2576  0.600000     0.1642
# 17378    Working Day      Clear  0.260000  0.2727  0.560000     0.1343
# 17379    Working Day      Clear  0.260000  0.2727  0.650000     0.1343
#
#          casual  registered  cnt
# instant
# 1           3.0        13.0   16
# 2           8.0        32.0   40
# 3           5.0        27.0   32
# 4           3.0        10.0   13
# 5           0.0         1.0    1
# ...         ...         ...  ...
# 17375      11.0       108.0  119
# 17376       8.0        81.0   89
# 17377       7.0        83.0   90
# 17378      13.0        48.0   61
# 17379      12.0        37.0   49
#
# [16874 rows x 16 columns]

# %% [markdown]
# Dropping the yr,mnth and hr column as the data is included in dteday feature

# %%
bike_df=bike_df.drop(['yr','mnth','hr'],axis=1)

# %%
bike_df
# Out:
#                      dteday    season holiday  weekday   workingday  \
# instant
# 1       2011-01-01 00:00:00  springer      No        6      No work
# 2       2011-01-01 01:00:00  springer      No        6      No work
# 3       2011-01-01 02:00:00  springer      No        6      No work
# 4       2011-01-01 03:00:00  springer      No        6      No work
# 5       2011-01-01 04:00:00  springer      No        6      No work
# ...                     ...       ...     ...      ...          ...
# 17375   2012-12-31 19:00:00  springer      No        1  Working Day
# 17376   2012-12-31 20:00:00  springer      No        1  Working Day
# 17377   2012-12-31 21:00:00  springer      No        1  Working Day
# 17378   2012-12-31 22:00:00  springer      No        1  Working Day
# 17379   2012-12-31 23:00:00  springer      No        1  Working Day
#
#         weathersit      temp   atemp       hum  windspeed  casual  registered  \
# instant
# 1            Clear  0.240000  0.2879  0.810000     0.0000     3.0        13.0
# 2            Clear  0.220000  0.2727  0.800000     0.0000     8.0        32.0
# 3            Clear  0.220000  0.2727  0.627208     0.0000     5.0        27.0
# 4            Clear  0.240000  0.2879  0.750000     0.0000     3.0        10.0
# 5            Clear  0.240000  0.2879  0.750000     0.0000     0.0         1.0
# ...            ...       ...     ...       ...        ...     ...         ...
# 17375         Mist  0.260000  0.2576  0.600000     0.1642    11.0       108.0
# 17376         Mist  0.260000  0.2576  0.600000     0.1642     8.0        81.0
# 17377        Clear  0.497132  0.2576  0.600000     0.1642     7.0        83.0
# 17378        Clear  0.260000  0.2727  0.560000     0.1343    13.0        48.0
# 17379        Clear  0.260000  0.2727  0.650000     0.1343    12.0        37.0
#
#          cnt
# instant
# 1         16
# 2         40
# 3         32
# 4         13
# 5          1
# ...      ...
# 17375    119
# 17376     89
# 17377     90
# 17378     61
# 17379     49
#
# [16874 rows x 13 columns]

# %% [markdown]
# ### Handling categorical variables through techniques like one-hot encoding or label encoding.

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lab=LabelEncoder()

# %%
for column in bike_df:
    if bike_df[column].dtype==object:
        bike_df[column]=lab.fit_transform(bike_df[column])

# %%
bike_df
# Out:
#                      dteday  season  holiday  weekday  workingday  weathersit  \
# instant
# 1       2011-01-01 00:00:00       1        0        6           0           0
# 2       2011-01-01 01:00:00       1        0        6           0           0
# 3       2011-01-01 02:00:00       1        0        6           0           0
# 4       2011-01-01 03:00:00       1        0        6           0           0
# 5       2011-01-01 04:00:00       1        0        6           0           0
# ...                     ...     ...      ...      ...         ...         ...
# 17375   2012-12-31 19:00:00       1        0        1           1           3
# 17376   2012-12-31 20:00:00       1        0        1           1           3
# 17377   2012-12-31 21:00:00       1        0        1           1           0
# 17378   2012-12-31 22:00:00       1        0        1           1           0
# 17379   2012-12-31 23:00:00       1        0        1           1           0
#
#              temp   atemp       hum  windspeed  casual  registered  cnt
# instant
# 1        0.240000  0.2879  0.810000     0.0000     3.0        13.0   16
# 2        0.220000  0.2727  0.800000     0.0000     8.0        32.0   40
# 3        0.220000  0.2727  0.627208     0.0000     5.0        27.0   32
# 4        0.240000  0.2879  0.750000     0.0000     3.0        10.0   13
# 5        0.240000  0.2879  0.750000     0.0000     0.0         1.0    1
# ...           ...     ...       ...        ...     ...         ...  ...
# 17375    0.260000  0.2576  0.600000     0.1642    11.0       108.0  119
# 17376    0.260000  0.2576  0.600000     0.1642     8.0        81.0   89
# 17377    0.497132  0.2576  0.600000     0.1642     7.0        83.0   90
# 17378    0.260000  0.2727  0.560000     0.1343    13.0        48.0   61
# 17379    0.260000  0.2727  0.650000     0.1343    12.0        37.0   49
#
# [16874 rows x 13 columns]

# %% [markdown]
# Since We are using the model that includes decision tree,we are using label encoder

# %% [markdown]
# ### Splitting the dataset into features and target

# %%
bike_df
# Out:
#                      dteday  season  holiday  weekday  workingday  weathersit  \
# instant
# 1       2011-01-01 00:00:00       1        0        6           0           0
# 2       2011-01-01 01:00:00       1        0        6           0           0
# 3       2011-01-01 02:00:00       1        0        6           0           0
# 4       2011-01-01 03:00:00       1        0        6           0           0
# 5       2011-01-01 04:00:00       1        0        6           0           0
# ...                     ...     ...      ...      ...         ...         ...
# 17375   2012-12-31 19:00:00       1        0        1           1           3
# 17376   2012-12-31 20:00:00       1        0        1           1           3
# 17377   2012-12-31 21:00:00       1        0        1           1           0
# 17378   2012-12-31 22:00:00       1        0        1           1           0
# 17379   2012-12-31 23:00:00       1        0        1           1           0
#
#              temp   atemp       hum  windspeed  casual  registered  cnt
# instant
# 1        0.240000  0.2879  0.810000     0.0000     3.0        13.0   16
# 2        0.220000  0.2727  0.800000     0.0000     8.0        32.0   40
# 3        0.220000  0.2727  0.627208     0.0000     5.0        27.0   32
# 4        0.240000  0.2879  0.750000     0.0000     3.0        10.0   13
# 5        0.240000  0.2879  0.750000     0.0000     0.0         1.0    1
# ...           ...     ...       ...        ...     ...         ...  ...
# 17375    0.260000  0.2576  0.600000     0.1642    11.0       108.0  119
# 17376    0.260000  0.2576  0.600000     0.1642     8.0        81.0   89
# 17377    0.497132  0.2576  0.600000     0.1642     7.0        83.0   90
# 17378    0.260000  0.2727  0.560000     0.1343    13.0        48.0   61
# 17379    0.260000  0.2727  0.650000     0.1343    12.0        37.0   49
#
# [16874 rows x 13 columns]

# %%
features=bike_df.drop('cnt',axis=1)
target=bike_df[['cnt']]

# %% [markdown]
# ### Scaling or normalizing numerical features to ensure uniformity in their ranges.

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
minmax=MinMaxScaler()

# %%
features.set_index('dteday', inplace=True)

# %%
scaled_df=minmax.fit_transform(features)

# %%
pickle.dump(minmax, open('scaler.pkl', 'wb'))

# %%
scaled_features = pd.DataFrame(scaled_df, columns=features.columns)

# %%
scaled_features.head()
# Out:
#      season  holiday  weekday  workingday  weathersit      temp   atemp  \
# 0  0.333333      0.0      1.0         0.0         0.0  0.224490  0.2879
# 1  0.333333      0.0      1.0         0.0         0.0  0.204082  0.2727
# 2  0.333333      0.0      1.0         0.0         0.0  0.204082  0.2727
# 3  0.333333      0.0      1.0         0.0         0.0  0.224490  0.2879
# 4  0.333333      0.0      1.0         0.0         0.0  0.224490  0.2879
#
#         hum  windspeed    casual  registered
# 0  0.810000        0.0  0.008475    0.020668
# 1  0.800000        0.0  0.022599    0.050874
# 2  0.627208        0.0  0.014124    0.042925
# 3  0.750000        0.0  0.008475    0.015898
# 4  0.750000        0.0  0.000000    0.001590

# %% [markdown]
# Data is ready to be used for model

# %% [markdown]
# # **4.Model Building:**
# # **5.Hyperparameter Tuning:**

# %% [markdown]
# ### Splitting the dataset into training and testing sets for model evaluation.

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(scaled_features,target,train_size=0.8,random_state=100)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (13499, 11)
# (3375, 11)
# (13499, 1)
# (3375, 1)

# %% [markdown]
# ### Selecting appropriate machine learning algorithms such as Decision Tree, Random Forest, and Gradient Boosting Regression for predicting bike rental demand.

# %% [markdown]
# #### Decision Tree

# %%
from sklearn.tree import DecisionTreeRegressor,plot_tree
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.model_selection import GridSearchCV

# %%
# Training the model
dectree=DecisionTreeRegressor(max_depth=5,min_samples_leaf=3,min_samples_split=5,random_state=100)

# %%
dt_model=dectree.fit(x_train,y_train)

# %%
## RMSE, MAE, or R-squared
y_pred=dt_model.predict(x_test)
rms_dt=np.sqrt(mean_squared_error(y_test,y_pred))
print("RMSE:",rms_dt)
mae_dt=mean_absolute_error(y_test,y_pred)
print("MAE:",mae_dt)
r2_dt=r2_score(y_test,y_pred)
print("R2:",r2_dt)
# Out:
# RMSE: 19.493920162296405
# MAE: 12.859604312408296
# R2: 0.984226230407217

# %%
## Plottig the decision tree
plt.figure(figsize=(10,8))
plot_tree(dt_model,filled=True,feature_names=x_train.columns)
plt.show()

# %%
## finding the best parameter using grid search
params={'max_depth':range(2,10),'min_samples_split':range(2,10),'min_samples_leaf':range(2,10)}
grid=GridSearchCV(dectree,params,verbose=2)

# %%
grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 512 candidates, totalling 2560 fits
# [CV] END max_depth=2, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=2, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=2, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=2, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=2, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=2, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=2, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=2, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=2, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=2, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=2, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=2, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=2, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=2, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=2, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=2, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=2, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=2, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=2, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=2, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=2, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=2, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=2, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=2, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=2, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=2, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=2, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=2, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=2, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=2, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=2, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=3, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=3, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=3, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=3, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=3, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=3, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=3, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=3, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=3, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=3, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=3, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=3, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=3, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=3, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=3, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=3, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=3, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=3, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=3, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=3, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=3, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=3, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=3, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=3, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=3, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=3, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=3, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=3, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=3, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=3, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=3, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=3, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=3, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=3, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=3, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=3, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=3, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=3, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=3, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=3, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=4, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=4, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=4, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=4, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=4, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=4, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=4, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=4, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=4, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=4, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=4, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=4, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=4, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=4, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=4, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=4, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=4, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=4, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=4, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=4, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=4, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=4, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=4, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=4, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=4, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=4, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=4, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=4, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=4, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=4, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=4, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=4, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=4, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=4, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=4, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=5, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=5, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=5, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=5, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=5, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=5, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=5, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=5, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=5, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=5, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=5, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=5, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=5, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=5, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=5, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=5, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=5, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=5, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=5, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=5, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=5, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=5, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=5, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=5, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=5, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=5, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=5, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=5, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=5, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=5, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=5, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=5, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=5, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=5, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=5, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=5, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=5, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=5, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=5, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=5, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=6, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=6, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=6, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=6, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=6, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=6, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=6, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=6, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=6, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=6, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=6, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=6, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=6, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=6, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=6, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=6, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=6, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=6, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=6, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=6, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=6, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=6, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=6, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=6, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=6, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=6, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=6, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=6, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=6, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=6, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=6, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=6, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=6, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=6, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=6, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=6, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=6, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=6, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=6, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=6, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=7, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=7, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=7, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=7, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=7, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=7, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=7, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=7, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=7, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=7, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=7, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=7, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=7, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=7, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=7, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=7, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=7, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=7, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=7, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=7, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=7, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=7, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=7, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=7, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=7, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=7, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=7, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=7, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=7, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=7, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=7, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=7, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=7, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=7, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=7, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=7, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=7, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=7, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=7, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=7, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=8, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=8, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=8, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=8, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=8, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=8, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=8, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=8, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=8, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=8, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=8, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=8, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=8, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=8, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=8, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=8, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=8, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=8, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=8, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=8, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=8, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=8, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=8, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=8, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=8, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=8, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=8, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=8, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=8, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=8, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=8, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=8, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=8, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=8, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=8, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=8, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=8, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=8, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=8, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=8, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=9, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=9, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=9, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=9, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=9, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=9, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=9, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=9, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=9, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=9, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=9, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=9, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=9, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=9, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=9, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=9, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=9, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=9, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=9, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=9, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=9, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=9, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=9, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=9, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=9, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=9, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=9, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=9, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=9, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=9, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=9, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=9, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=9, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=9, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=9, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=9, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=9, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=9, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=9, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=2, min_samples_leaf=9, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=2, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=2, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=2, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=2, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=2, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=2, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=2, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=2, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=2, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=2, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=2, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=2, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=2, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=2, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=2, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=2, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=2, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=2, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=2, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=2, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=2, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=2, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=2, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=2, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=2, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=2, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=2, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=2, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=2, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=2, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=3, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=3, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=3, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=3, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=3, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=3, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=3, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=3, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=3, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=3, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=3, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=3, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=3, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=3, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=3, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=3, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=3, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=3, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=3, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=3, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=3, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=3, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=3, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=3, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=3, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=3, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=3, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=3, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=3, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=3, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=3, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=3, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=3, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=3, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=3, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=3, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=3, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=3, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=3, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=3, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=4, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=4, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=4, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=4, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=4, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=4, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=4, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=4, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=4, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=4, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=4, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=4, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=4, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=4, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=4, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=4, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=4, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=4, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=4, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=4, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=4, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=4, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=4, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=4, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=4, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=4, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=4, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=4, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=4, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=4, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=4, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=4, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=4, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=4, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=4, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=5, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=5, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=5, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=5, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=5, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=5, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=5, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=5, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=5, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=5, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=5, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=5, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=5, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=5, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=5, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=5, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=5, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=5, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=5, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=5, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=5, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=5, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=5, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=5, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=5, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=5, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=5, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=5, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=5, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=5, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=5, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=5, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=5, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=5, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=5, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=5, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=5, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=5, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=5, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=5, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=6, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=6, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=6, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=6, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=6, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=6, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=6, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=6, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=6, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=6, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=6, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=6, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=6, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=6, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=6, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=6, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=6, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=6, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=6, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=6, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=6, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=6, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=6, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=6, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=6, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=6, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=6, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=6, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=6, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=6, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=6, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=6, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=6, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=6, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=6, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=6, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=6, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=6, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=6, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=6, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=7, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=7, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=7, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=7, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=7, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=7, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=7, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=7, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=7, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=7, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=7, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=7, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=7, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=7, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=7, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=7, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=7, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=7, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=7, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=7, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=7, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=7, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=7, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=7, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=7, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=7, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=7, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=7, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=7, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=7, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=7, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=7, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=7, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=7, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=7, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=7, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=7, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=7, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=7, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=7, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=8, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=8, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=8, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=8, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=8, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=8, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=8, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=8, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=8, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=8, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=8, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=8, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=8, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=8, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=8, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=8, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=8, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=8, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=8, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=8, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=8, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=8, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=8, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=3, min_samples_leaf=8, min_samples_split=6; total time=   0.0s
# ...
# [CV] END max_depth=9, min_samples_leaf=5, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=5, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=5, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=5, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=5, min_samples_split=4; total time=   0.1s
# [CV] END max_depth=9, min_samples_leaf=5, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=5, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=5, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=5, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=5, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=5, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=5, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=5, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=5, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=5, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=5, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=5, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=5, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=5, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=5, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=5, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=5, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=5, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=5, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=5, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=5, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=5, min_samples_split=9; total time=   0.1s
# [CV] END max_depth=9, min_samples_leaf=5, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=5, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=5, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=6, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=6, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=6, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=6, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=6, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=6, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=6, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=6, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=6, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=6, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=6, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=6, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=6, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=6, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=6, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=6, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=6, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=6, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=6, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=6, min_samples_split=5; total time=   0.1s
# [CV] END max_depth=9, min_samples_leaf=6, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=6, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=6, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=6, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=6, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=6, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=6, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=6, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=6, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=6, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=6, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=6, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=6, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=6, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=6, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=6, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=6, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=6, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=6, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=6, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=7, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=7, min_samples_split=2; total time=   0.1s
# [CV] END max_depth=9, min_samples_leaf=7, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=7, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=7, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=7, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=7, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=7, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=7, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=7, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=7, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=7, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=7, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=7, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=7, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=7, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=7, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=7, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=7, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=7, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=7, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=7, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=7, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=7, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=7, min_samples_split=6; total time=   0.1s
# [CV] END max_depth=9, min_samples_leaf=7, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=7, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=7, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=7, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=7, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=7, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=7, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=7, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=7, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=7, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=7, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=7, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=7, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=7, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=7, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=8, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=8, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=8, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=8, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=8, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=8, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=8, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=8, min_samples_split=3; total time=   0.1s
# [CV] END max_depth=9, min_samples_leaf=8, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=8, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=8, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=8, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=8, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=8, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=8, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=8, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=8, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=8, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=8, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=8, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=8, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=8, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=8, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=8, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=8, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=8, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=8, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=8, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=8, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=8, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=8, min_samples_split=8; total time=   0.1s
# [CV] END max_depth=9, min_samples_leaf=8, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=8, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=8, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=8, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=8, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=8, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=8, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=8, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=8, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=9, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=9, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=9, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=9, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=9, min_samples_split=2; total time=   0.1s
# [CV] END max_depth=9, min_samples_leaf=9, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=9, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=9, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=9, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=9, min_samples_split=3; total time=   0.1s
# [CV] END max_depth=9, min_samples_leaf=9, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=9, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=9, min_samples_split=4; total time=   0.1s
# [CV] END max_depth=9, min_samples_leaf=9, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=9, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=9, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=9, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=9, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=9, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=9, min_samples_split=5; total time=   0.1s
# [CV] END max_depth=9, min_samples_leaf=9, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=9, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=9, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=9, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=9, min_samples_split=6; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=9, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=9, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=9, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=9, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=9, min_samples_split=7; total time=   0.1s
# [CV] END max_depth=9, min_samples_leaf=9, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=9, min_samples_split=8; total time=   0.1s
# [CV] END max_depth=9, min_samples_leaf=9, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=9, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=9, min_samples_split=8; total time=   0.1s
# [CV] END max_depth=9, min_samples_leaf=9, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=9, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=9, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=9, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=9, min_samples_split=9; total time=   0.1s
# GridSearchCV(estimator=DecisionTreeRegressor(max_depth=5, min_samples_leaf=3,
#                                              min_samples_split=5,
#                                              random_state=100),
#              param_grid={'max_depth': range(2, 10),
#                          'min_samples_leaf': range(2, 10),
#                          'min_samples_split': range(2, 10)},
#              verbose=2)

# %%
grid.best_params_
# Out:
# {'max_depth': 9, 'min_samples_leaf': 3, 'min_samples_split': 2}

# %%
## Building decision tree model with best params
dectree2=DecisionTreeRegressor(max_depth=9,min_samples_leaf=3,min_samples_split=2,random_state=100)

# %%
dt_model2=dectree2.fit(x_train,y_train)

# %%
## RMSE, MAE, or R-squared of best parameters model
y_pred_dt2=dt_model2.predict(x_test)
rms_dt2=np.sqrt(mean_squared_error(y_test,y_pred_dt2))
print("RMSE:",rms_dt2)
mae_dt2=mean_absolute_error(y_test,y_pred_dt2)
print("MAE:",mae_dt2)
r2_dt2=r2_score(y_test,y_pred_dt2)
print("R2:",r2_dt2)
# Out:
# RMSE: 6.114055424571977
# MAE: 3.5846335014168327
# R2: 0.9984483424843208

# %%
train_pred_dt2=dt_model2.predict(x_train)
train_rmse_dt2= mean_squared_error(y_train, train_pred_dt2)
test_rmse_dt2= mean_squared_error(y_test, y_pred)

print(f"Train RMSE: {train_rmse_dt2}")
print(f"Test RMSE: {test_rmse_dt2}")
# Out:
# Train RMSE: 19.880647034099418
# Test RMSE: 380.01292329398626

# %%
## Overfitting Check: If the training RMSE is much smaller than the test RMSE, the model may be overfitting.
## The RMSE of training data is very less than testing data RMSE,so the model is overfitting

# %% [markdown]
# #### Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rand_for=RandomForestRegressor(n_estimators=100,max_depth=5,min_samples_leaf=3,min_samples_split=5,random_state=100,bootstrap=False)

# %%
rand_model=rand_for.fit(x_train,y_train)

# %%
## RMSE, MAE, or R-squared
y_pred_rand=rand_model.predict(x_test)
rms_rand=np.sqrt(mean_squared_error(y_test,y_pred_rand))
print("RMSE:",rms_rand)
mae_rand=mean_absolute_error(y_test,y_pred_rand)
print("MAE:",mae_rand)
r2_rand=r2_score(y_test,y_pred_rand)
print("R2:",r2_rand)
# Out:
# RMSE: 19.49392016229641
# MAE: 12.859604312408297
# R2: 0.984226230407217

# %%
##using grid search to find best parameters
params_rand={'n_estimators':range(50,100),'bootstrap':[True,False]}
grid_sch_rand=GridSearchCV(rand_for,params_rand,verbose=2)

# %%
grid_sch_rand.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [CV] END ....................bootstrap=True, n_estimators=50; total time=   0.8s
# [CV] END ....................bootstrap=True, n_estimators=50; total time=   0.7s
# [CV] END ....................bootstrap=True, n_estimators=50; total time=   1.0s
# [CV] END ....................bootstrap=True, n_estimators=50; total time=   0.9s
# [CV] END ....................bootstrap=True, n_estimators=50; total time=   0.7s
# [CV] END ....................bootstrap=True, n_estimators=51; total time=   0.8s
# [CV] END ....................bootstrap=True, n_estimators=51; total time=   1.1s
# [CV] END ....................bootstrap=True, n_estimators=51; total time=   0.9s
# [CV] END ....................bootstrap=True, n_estimators=51; total time=   0.8s
# [CV] END ....................bootstrap=True, n_estimators=51; total time=   0.7s
# [CV] END ....................bootstrap=True, n_estimators=52; total time=   0.8s
# [CV] END ....................bootstrap=True, n_estimators=52; total time=   0.8s
# [CV] END ....................bootstrap=True, n_estimators=52; total time=   1.0s
# [CV] END ....................bootstrap=True, n_estimators=52; total time=   2.1s
# [CV] END ....................bootstrap=True, n_estimators=52; total time=   1.3s
# [CV] END ....................bootstrap=True, n_estimators=53; total time=   0.8s
# [CV] END ....................bootstrap=True, n_estimators=53; total time=   0.8s
# [CV] END ....................bootstrap=True, n_estimators=53; total time=   0.8s
# [CV] END ....................bootstrap=True, n_estimators=53; total time=   0.8s
# [CV] END ....................bootstrap=True, n_estimators=53; total time=   0.8s
# [CV] END ....................bootstrap=True, n_estimators=54; total time=   0.8s
# [CV] END ....................bootstrap=True, n_estimators=54; total time=   0.8s
# [CV] END ....................bootstrap=True, n_estimators=54; total time=   0.8s
# [CV] END ....................bootstrap=True, n_estimators=54; total time=   0.8s
# [CV] END ....................bootstrap=True, n_estimators=54; total time=   0.8s
# [CV] END ....................bootstrap=True, n_estimators=55; total time=   0.8s
# [CV] END ....................bootstrap=True, n_estimators=55; total time=   0.8s
# [CV] END ....................bootstrap=True, n_estimators=55; total time=   1.1s
# [CV] END ....................bootstrap=True, n_estimators=55; total time=   1.1s
# [CV] END ....................bootstrap=True, n_estimators=55; total time=   1.2s
# [CV] END ....................bootstrap=True, n_estimators=56; total time=   0.9s
# [CV] END ....................bootstrap=True, n_estimators=56; total time=   0.8s
# [CV] END ....................bootstrap=True, n_estimators=56; total time=   0.8s
# [CV] END ....................bootstrap=True, n_estimators=56; total time=   0.8s
# [CV] END ....................bootstrap=True, n_estimators=56; total time=   0.8s
# [CV] END ....................bootstrap=True, n_estimators=57; total time=   0.8s
# [CV] END ....................bootstrap=True, n_estimators=57; total time=   0.8s
# [CV] END ....................bootstrap=True, n_estimators=57; total time=   0.8s
# [CV] END ....................bootstrap=True, n_estimators=57; total time=   0.8s
# [CV] END ....................bootstrap=True, n_estimators=57; total time=   0.8s
# [CV] END ....................bootstrap=True, n_estimators=58; total time=   0.9s
# [CV] END ....................bootstrap=True, n_estimators=58; total time=   0.9s
# [CV] END ....................bootstrap=True, n_estimators=58; total time=   1.2s
# [CV] END ....................bootstrap=True, n_estimators=58; total time=   1.2s
# [CV] END ....................bootstrap=True, n_estimators=58; total time=   1.2s
# [CV] END ....................bootstrap=True, n_estimators=59; total time=   0.9s
# [CV] END ....................bootstrap=True, n_estimators=59; total time=   0.9s
# [CV] END ....................bootstrap=True, n_estimators=59; total time=   0.9s
# [CV] END ....................bootstrap=True, n_estimators=59; total time=   0.9s
# [CV] END ....................bootstrap=True, n_estimators=59; total time=   0.9s
# [CV] END ....................bootstrap=True, n_estimators=60; total time=   0.9s
# [CV] END ....................bootstrap=True, n_estimators=60; total time=   0.9s
# [CV] END ....................bootstrap=True, n_estimators=60; total time=   0.9s
# [CV] END ....................bootstrap=True, n_estimators=60; total time=   0.9s
# [CV] END ....................bootstrap=True, n_estimators=60; total time=   0.9s
# [CV] END ....................bootstrap=True, n_estimators=61; total time=   0.9s
# [CV] END ....................bootstrap=True, n_estimators=61; total time=   1.1s
# [CV] END ....................bootstrap=True, n_estimators=61; total time=   1.3s
# [CV] END ....................bootstrap=True, n_estimators=61; total time=   1.3s
# [CV] END ....................bootstrap=True, n_estimators=61; total time=   1.0s
# [CV] END ....................bootstrap=True, n_estimators=62; total time=   0.9s
# [CV] END ....................bootstrap=True, n_estimators=62; total time=   0.9s
# [CV] END ....................bootstrap=True, n_estimators=62; total time=   0.9s
# [CV] END ....................bootstrap=True, n_estimators=62; total time=   0.9s
# [CV] END ....................bootstrap=True, n_estimators=62; total time=   0.9s
# [CV] END ....................bootstrap=True, n_estimators=63; total time=   0.9s
# [CV] END ....................bootstrap=True, n_estimators=63; total time=   0.9s
# [CV] END ....................bootstrap=True, n_estimators=63; total time=   1.0s
# [CV] END ....................bootstrap=True, n_estimators=63; total time=   2.6s
# [CV] END ....................bootstrap=True, n_estimators=63; total time=   3.9s
# [CV] END ....................bootstrap=True, n_estimators=64; total time=   1.4s
# [CV] END ....................bootstrap=True, n_estimators=64; total time=   0.9s
# [CV] END ....................bootstrap=True, n_estimators=64; total time=   0.9s
# [CV] END ....................bootstrap=True, n_estimators=64; total time=   0.9s
# [CV] END ....................bootstrap=True, n_estimators=64; total time=   0.9s
# [CV] END ....................bootstrap=True, n_estimators=65; total time=   1.0s
# [CV] END ....................bootstrap=True, n_estimators=65; total time=   1.0s
# [CV] END ....................bootstrap=True, n_estimators=65; total time=   0.9s
# [CV] END ....................bootstrap=True, n_estimators=65; total time=   1.0s
# [CV] END ....................bootstrap=True, n_estimators=65; total time=   1.0s
# [CV] END ....................bootstrap=True, n_estimators=66; total time=   1.3s
# [CV] END ....................bootstrap=True, n_estimators=66; total time=   1.4s
# [CV] END ....................bootstrap=True, n_estimators=66; total time=   1.2s
# [CV] END ....................bootstrap=True, n_estimators=66; total time=   1.0s
# [CV] END ....................bootstrap=True, n_estimators=66; total time=   1.0s
# [CV] END ....................bootstrap=True, n_estimators=67; total time=   1.0s
# [CV] END ....................bootstrap=True, n_estimators=67; total time=   1.0s
# [CV] END ....................bootstrap=True, n_estimators=67; total time=   1.0s
# [CV] END ....................bootstrap=True, n_estimators=67; total time=   1.0s
# [CV] END ....................bootstrap=True, n_estimators=67; total time=   1.0s
# [CV] END ....................bootstrap=True, n_estimators=68; total time=   1.0s
# [CV] END ....................bootstrap=True, n_estimators=68; total time=   1.0s
# [CV] END ....................bootstrap=True, n_estimators=68; total time=   1.2s
# [CV] END ....................bootstrap=True, n_estimators=68; total time=   1.4s
# [CV] END ....................bootstrap=True, n_estimators=68; total time=   1.4s
# [CV] END ....................bootstrap=True, n_estimators=69; total time=   1.0s
# [CV] END ....................bootstrap=True, n_estimators=69; total time=   1.0s
# [CV] END ....................bootstrap=True, n_estimators=69; total time=   1.0s
# [CV] END ....................bootstrap=True, n_estimators=69; total time=   1.0s
# [CV] END ....................bootstrap=True, n_estimators=69; total time=   1.0s
# [CV] END ....................bootstrap=True, n_estimators=70; total time=   1.0s
# [CV] END ....................bootstrap=True, n_estimators=70; total time=   1.0s
# [CV] END ....................bootstrap=True, n_estimators=70; total time=   1.0s
# [CV] END ....................bootstrap=True, n_estimators=70; total time=   1.0s
# [CV] END ....................bootstrap=True, n_estimators=70; total time=   1.1s
# [CV] END ....................bootstrap=True, n_estimators=71; total time=   1.5s
# [CV] END ....................bootstrap=True, n_estimators=71; total time=   1.5s
# [CV] END ....................bootstrap=True, n_estimators=71; total time=   1.2s
# [CV] END ....................bootstrap=True, n_estimators=71; total time=   1.0s
# [CV] END ....................bootstrap=True, n_estimators=71; total time=   1.5s
# [CV] END ....................bootstrap=True, n_estimators=72; total time=   1.1s
# [CV] END ....................bootstrap=True, n_estimators=72; total time=   1.1s
# [CV] END ....................bootstrap=True, n_estimators=72; total time=   1.1s
# [CV] END ....................bootstrap=True, n_estimators=72; total time=   1.1s
# [CV] END ....................bootstrap=True, n_estimators=72; total time=   1.1s
# [CV] END ....................bootstrap=True, n_estimators=73; total time=   1.1s
# [CV] END ....................bootstrap=True, n_estimators=73; total time=   1.4s
# [CV] END ....................bootstrap=True, n_estimators=73; total time=   1.5s
# [CV] END ....................bootstrap=True, n_estimators=73; total time=   1.4s
# [CV] END ....................bootstrap=True, n_estimators=73; total time=   1.1s
# [CV] END ....................bootstrap=True, n_estimators=74; total time=   1.1s
# [CV] END ....................bootstrap=True, n_estimators=74; total time=   1.1s
# [CV] END ....................bootstrap=True, n_estimators=74; total time=   1.1s
# [CV] END ....................bootstrap=True, n_estimators=74; total time=   1.1s
# [CV] END ....................bootstrap=True, n_estimators=74; total time=   1.1s
# [CV] END ....................bootstrap=True, n_estimators=75; total time=   1.1s
# [CV] END ....................bootstrap=True, n_estimators=75; total time=   1.1s
# [CV] END ....................bootstrap=True, n_estimators=75; total time=   1.1s
# [CV] END ....................bootstrap=True, n_estimators=75; total time=   1.5s
# [CV] END ....................bootstrap=True, n_estimators=75; total time=   1.6s
# [CV] END ....................bootstrap=True, n_estimators=76; total time=   1.2s
# [CV] END ....................bootstrap=True, n_estimators=76; total time=   1.1s
# [CV] END ....................bootstrap=True, n_estimators=76; total time=   1.1s
# [CV] END ....................bootstrap=True, n_estimators=76; total time=   1.1s
# [CV] END ....................bootstrap=True, n_estimators=76; total time=   1.1s
# [CV] END ....................bootstrap=True, n_estimators=77; total time=   1.1s
# [CV] END ....................bootstrap=True, n_estimators=77; total time=   1.1s
# [CV] END ....................bootstrap=True, n_estimators=77; total time=   1.1s
# [CV] END ....................bootstrap=True, n_estimators=77; total time=   1.1s
# [CV] END ....................bootstrap=True, n_estimators=77; total time=   1.5s
# [CV] END ....................bootstrap=True, n_estimators=78; total time=   1.6s
# [CV] END ....................bootstrap=True, n_estimators=78; total time=   1.3s
# [CV] END ....................bootstrap=True, n_estimators=78; total time=   1.1s
# [CV] END ....................bootstrap=True, n_estimators=78; total time=   1.1s
# [CV] END ....................bootstrap=True, n_estimators=78; total time=   1.1s
# [CV] END ....................bootstrap=True, n_estimators=79; total time=   1.2s
# [CV] END ....................bootstrap=True, n_estimators=79; total time=   1.2s
# [CV] END ....................bootstrap=True, n_estimators=79; total time=   1.2s
# [CV] END ....................bootstrap=True, n_estimators=79; total time=   1.2s
# [CV] END ....................bootstrap=True, n_estimators=79; total time=   1.2s
# [CV] END ....................bootstrap=True, n_estimators=80; total time=   1.7s
# [CV] END ....................bootstrap=True, n_estimators=80; total time=   1.6s
# [CV] END ....................bootstrap=True, n_estimators=80; total time=   1.2s
# [CV] END ....................bootstrap=True, n_estimators=80; total time=   1.2s
# [CV] END ....................bootstrap=True, n_estimators=80; total time=   1.2s
# [CV] END ....................bootstrap=True, n_estimators=81; total time=   1.6s
# [CV] END ....................bootstrap=True, n_estimators=81; total time=   1.2s
# [CV] END ....................bootstrap=True, n_estimators=81; total time=   1.2s
# [CV] END ....................bootstrap=True, n_estimators=81; total time=   1.2s
# [CV] END ....................bootstrap=True, n_estimators=81; total time=   1.2s
# [CV] END ....................bootstrap=True, n_estimators=82; total time=   1.7s
# [CV] END ....................bootstrap=True, n_estimators=82; total time=   2.2s
# [CV] END ....................bootstrap=True, n_estimators=82; total time=   1.6s
# [CV] END ....................bootstrap=True, n_estimators=82; total time=   1.2s
# [CV] END ....................bootstrap=True, n_estimators=82; total time=   1.2s
# [CV] END ....................bootstrap=True, n_estimators=83; total time=   1.2s
# [CV] END ....................bootstrap=True, n_estimators=83; total time=   1.2s
# [CV] END ....................bootstrap=True, n_estimators=83; total time=   1.2s
# [CV] END ....................bootstrap=True, n_estimators=83; total time=   1.2s
# [CV] END ....................bootstrap=True, n_estimators=83; total time=   1.4s
# [CV] END ....................bootstrap=True, n_estimators=84; total time=   1.7s
# [CV] END ....................bootstrap=True, n_estimators=84; total time=   1.6s
# [CV] END ....................bootstrap=True, n_estimators=84; total time=   1.2s
# [CV] END ....................bootstrap=True, n_estimators=84; total time=   1.2s
# [CV] END ....................bootstrap=True, n_estimators=84; total time=   1.2s
# [CV] END ....................bootstrap=True, n_estimators=85; total time=   1.2s
# [CV] END ....................bootstrap=True, n_estimators=85; total time=   1.2s
# [CV] END ....................bootstrap=True, n_estimators=85; total time=   1.2s
# [CV] END ....................bootstrap=True, n_estimators=85; total time=   1.2s
# [CV] END ....................bootstrap=True, n_estimators=85; total time=   1.3s
# [CV] END ....................bootstrap=True, n_estimators=86; total time=   1.8s
# [CV] END ....................bootstrap=True, n_estimators=86; total time=   1.7s
# [CV] END ....................bootstrap=True, n_estimators=86; total time=   1.3s
# [CV] END ....................bootstrap=True, n_estimators=86; total time=   1.3s
# [CV] END ....................bootstrap=True, n_estimators=86; total time=   1.3s
# [CV] END ....................bootstrap=True, n_estimators=87; total time=   1.3s
# [CV] END ....................bootstrap=True, n_estimators=87; total time=   1.3s
# [CV] END ....................bootstrap=True, n_estimators=87; total time=   1.3s
# [CV] END ....................bootstrap=True, n_estimators=87; total time=   1.3s
# [CV] END ....................bootstrap=True, n_estimators=87; total time=   1.3s
# [CV] END ....................bootstrap=True, n_estimators=88; total time=   1.8s
# [CV] END ....................bootstrap=True, n_estimators=88; total time=   1.7s
# [CV] END ....................bootstrap=True, n_estimators=88; total time=   1.3s
# [CV] END ....................bootstrap=True, n_estimators=88; total time=   1.3s
# [CV] END ....................bootstrap=True, n_estimators=88; total time=   1.3s
# [CV] END ....................bootstrap=True, n_estimators=89; total time=   1.3s
# [CV] END ....................bootstrap=True, n_estimators=89; total time=   1.3s
# [CV] END ....................bootstrap=True, n_estimators=89; total time=   1.3s
# [CV] END ....................bootstrap=True, n_estimators=89; total time=   1.3s
# [CV] END ....................bootstrap=True, n_estimators=89; total time=   1.5s
# [CV] END ....................bootstrap=True, n_estimators=90; total time=   1.9s
# [CV] END ....................bootstrap=True, n_estimators=90; total time=   1.4s
# [CV] END ....................bootstrap=True, n_estimators=90; total time=   1.3s
# [CV] END ....................bootstrap=True, n_estimators=90; total time=   1.3s
# [CV] END ....................bootstrap=True, n_estimators=90; total time=   1.3s
# [CV] END ....................bootstrap=True, n_estimators=91; total time=   1.3s
# [CV] END ....................bootstrap=True, n_estimators=91; total time=   1.3s
# [CV] END ....................bootstrap=True, n_estimators=91; total time=   1.3s
# [CV] END ....................bootstrap=True, n_estimators=91; total time=   1.5s
# [CV] END ....................bootstrap=True, n_estimators=91; total time=   1.9s
# [CV] END ....................bootstrap=True, n_estimators=92; total time=   1.7s
# [CV] END ....................bootstrap=True, n_estimators=92; total time=   1.3s
# [CV] END ....................bootstrap=True, n_estimators=92; total time=   1.3s
# [CV] END ....................bootstrap=True, n_estimators=92; total time=   1.4s
# [CV] END ....................bootstrap=True, n_estimators=92; total time=   1.4s
# [CV] END ....................bootstrap=True, n_estimators=93; total time=   1.4s
# [CV] END ....................bootstrap=True, n_estimators=93; total time=   1.4s
# [CV] END ....................bootstrap=True, n_estimators=93; total time=   1.4s
# [CV] END ....................bootstrap=True, n_estimators=93; total time=   1.9s
# [CV] END ....................bootstrap=True, n_estimators=93; total time=   1.9s
# [CV] END ....................bootstrap=True, n_estimators=94; total time=   1.4s
# [CV] END ....................bootstrap=True, n_estimators=94; total time=   1.4s
# [CV] END ....................bootstrap=True, n_estimators=94; total time=   1.4s
# [CV] END ....................bootstrap=True, n_estimators=94; total time=   1.4s
# [CV] END ....................bootstrap=True, n_estimators=94; total time=   1.4s
# [CV] END ....................bootstrap=True, n_estimators=95; total time=   1.4s
# [CV] END ....................bootstrap=True, n_estimators=95; total time=   1.4s
# [CV] END ....................bootstrap=True, n_estimators=95; total time=   1.9s
# [CV] END ....................bootstrap=True, n_estimators=95; total time=   1.8s
# [CV] END ....................bootstrap=True, n_estimators=95; total time=   1.4s
# [CV] END ....................bootstrap=True, n_estimators=96; total time=   1.4s
# [CV] END ....................bootstrap=True, n_estimators=96; total time=   1.4s
# [CV] END ....................bootstrap=True, n_estimators=96; total time=   1.4s
# [CV] END ....................bootstrap=True, n_estimators=96; total time=   1.4s
# [CV] END ....................bootstrap=True, n_estimators=96; total time=   1.4s
# [CV] END ....................bootstrap=True, n_estimators=97; total time=   1.5s
# [CV] END ....................bootstrap=True, n_estimators=97; total time=   2.0s
# [CV] END ....................bootstrap=True, n_estimators=97; total time=   1.8s
# [CV] END ....................bootstrap=True, n_estimators=97; total time=   1.4s
# [CV] END ....................bootstrap=True, n_estimators=97; total time=   1.4s
# [CV] END ....................bootstrap=True, n_estimators=98; total time=   1.4s
# [CV] END ....................bootstrap=True, n_estimators=98; total time=   1.4s
# [CV] END ....................bootstrap=True, n_estimators=98; total time=   1.4s
# [CV] END ....................bootstrap=True, n_estimators=98; total time=   1.4s
# [CV] END ....................bootstrap=True, n_estimators=98; total time=   1.6s
# [CV] END ....................bootstrap=True, n_estimators=99; total time=   2.1s
# [CV] END ....................bootstrap=True, n_estimators=99; total time=   1.7s
# [CV] END ....................bootstrap=True, n_estimators=99; total time=   1.4s
# [CV] END ....................bootstrap=True, n_estimators=99; total time=   1.5s
# [CV] END ....................bootstrap=True, n_estimators=99; total time=   1.5s
# [CV] END ...................bootstrap=False, n_estimators=50; total time=   1.0s
# [CV] END ...................bootstrap=False, n_estimators=50; total time=   1.0s
# [CV] END ...................bootstrap=False, n_estimators=50; total time=   1.0s
# [CV] END ...................bootstrap=False, n_estimators=50; total time=   1.0s
# [CV] END ...................bootstrap=False, n_estimators=50; total time=   1.1s
# [CV] END ...................bootstrap=False, n_estimators=51; total time=   1.4s
# [CV] END ...................bootstrap=False, n_estimators=51; total time=   1.4s
# [CV] END ...................bootstrap=False, n_estimators=51; total time=   1.1s
# [CV] END ...................bootstrap=False, n_estimators=51; total time=   1.0s
# [CV] END ...................bootstrap=False, n_estimators=51; total time=   1.0s
# [CV] END ...................bootstrap=False, n_estimators=52; total time=   1.0s
# [CV] END ...................bootstrap=False, n_estimators=52; total time=   1.0s
# [CV] END ...................bootstrap=False, n_estimators=52; total time=   1.0s
# [CV] END ...................bootstrap=False, n_estimators=52; total time=   1.0s
# [CV] END ...................bootstrap=False, n_estimators=52; total time=   1.0s
# [CV] END ...................bootstrap=False, n_estimators=53; total time=   1.1s
# [CV] END ...................bootstrap=False, n_estimators=53; total time=   1.1s
# [CV] END ...................bootstrap=False, n_estimators=53; total time=   1.5s
# [CV] END ...................bootstrap=False, n_estimators=53; total time=   1.5s
# [CV] END ...................bootstrap=False, n_estimators=53; total time=   1.2s
# [CV] END ...................bootstrap=False, n_estimators=54; total time=   1.1s
# [CV] END ...................bootstrap=False, n_estimators=54; total time=   1.1s
# [CV] END ...................bootstrap=False, n_estimators=54; total time=   1.1s
# [CV] END ...................bootstrap=False, n_estimators=54; total time=   1.1s
# [CV] END ...................bootstrap=False, n_estimators=54; total time=   1.1s
# [CV] END ...................bootstrap=False, n_estimators=55; total time=   1.1s
# [CV] END ...................bootstrap=False, n_estimators=55; total time=   1.1s
# [CV] END ...................bootstrap=False, n_estimators=55; total time=   1.1s
# [CV] END ...................bootstrap=False, n_estimators=55; total time=   1.3s
# [CV] END ...................bootstrap=False, n_estimators=55; total time=   1.5s
# [CV] END ...................bootstrap=False, n_estimators=56; total time=   1.5s
# [CV] END ...................bootstrap=False, n_estimators=56; total time=   1.1s
# [CV] END ...................bootstrap=False, n_estimators=56; total time=   1.1s
# [CV] END ...................bootstrap=False, n_estimators=56; total time=   1.1s
# [CV] END ...................bootstrap=False, n_estimators=56; total time=   1.1s
# [CV] END ...................bootstrap=False, n_estimators=57; total time=   1.1s
# [CV] END ...................bootstrap=False, n_estimators=57; total time=   1.1s
# [CV] END ...................bootstrap=False, n_estimators=57; total time=   1.1s
# [CV] END ...................bootstrap=False, n_estimators=57; total time=   1.1s
# [CV] END ...................bootstrap=False, n_estimators=57; total time=   1.2s
# [CV] END ...................bootstrap=False, n_estimators=58; total time=   1.6s
# [CV] END ...................bootstrap=False, n_estimators=58; total time=   1.6s
# [CV] END ...................bootstrap=False, n_estimators=58; total time=   1.2s
# [CV] END ...................bootstrap=False, n_estimators=58; total time=   1.2s
# [CV] END ...................bootstrap=False, n_estimators=58; total time=   1.2s
# [CV] END ...................bootstrap=False, n_estimators=59; total time=   1.2s
# [CV] END ...................bootstrap=False, n_estimators=59; total time=   1.2s
# [CV] END ...................bootstrap=False, n_estimators=59; total time=   1.2s
# [CV] END ...................bootstrap=False, n_estimators=59; total time=   1.2s
# [CV] END ...................bootstrap=False, n_estimators=59; total time=   1.2s
# [CV] END ...................bootstrap=False, n_estimators=60; total time=   1.4s
# [CV] END ...................bootstrap=False, n_estimators=60; total time=   1.7s
# [CV] END ...................bootstrap=False, n_estimators=60; total time=   1.6s
# [CV] END ...................bootstrap=False, n_estimators=60; total time=   1.2s
# [CV] END ...................bootstrap=False, n_estimators=60; total time=   1.2s
# [CV] END ...................bootstrap=False, n_estimators=61; total time=   1.3s
# [CV] END ...................bootstrap=False, n_estimators=61; total time=   1.2s
# [CV] END ...................bootstrap=False, n_estimators=61; total time=   1.2s
# [CV] END ...................bootstrap=False, n_estimators=61; total time=   1.2s
# [CV] END ...................bootstrap=False, n_estimators=61; total time=   1.2s
# [CV] END ...................bootstrap=False, n_estimators=62; total time=   1.2s
# [CV] END ...................bootstrap=False, n_estimators=62; total time=   1.7s
# [CV] END ...................bootstrap=False, n_estimators=62; total time=   1.7s
# [CV] END ...................bootstrap=False, n_estimators=62; total time=   1.3s
# [CV] END ...................bootstrap=False, n_estimators=62; total time=   1.2s
# [CV] END ...................bootstrap=False, n_estimators=63; total time=   1.3s
# [CV] END ...................bootstrap=False, n_estimators=63; total time=   1.3s
# [CV] END ...................bootstrap=False, n_estimators=63; total time=   1.3s
# [CV] END ...................bootstrap=False, n_estimators=63; total time=   1.3s
# [CV] END ...................bootstrap=False, n_estimators=63; total time=   1.3s
# [CV] END ...................bootstrap=False, n_estimators=64; total time=   1.3s
# [CV] END ...................bootstrap=False, n_estimators=64; total time=   1.8s
# [CV] END ...................bootstrap=False, n_estimators=64; total time=   1.8s
# [CV] END ...................bootstrap=False, n_estimators=64; total time=   1.3s
# [CV] END ...................bootstrap=False, n_estimators=64; total time=   1.3s
# [CV] END ...................bootstrap=False, n_estimators=65; total time=   1.3s
# [CV] END ...................bootstrap=False, n_estimators=65; total time=   1.3s
# [CV] END ...................bootstrap=False, n_estimators=65; total time=   1.3s
# [CV] END ...................bootstrap=False, n_estimators=65; total time=   1.3s
# [CV] END ...................bootstrap=False, n_estimators=65; total time=   1.3s
# [CV] END ...................bootstrap=False, n_estimators=66; total time=   1.5s
# [CV] END ...................bootstrap=False, n_estimators=66; total time=   1.8s
# [CV] END ...................bootstrap=False, n_estimators=66; total time=   1.7s
# [CV] END ...................bootstrap=False, n_estimators=66; total time=   1.3s
# [CV] END ...................bootstrap=False, n_estimators=66; total time=   1.3s
# [CV] END ...................bootstrap=False, n_estimators=67; total time=   1.3s
# [CV] END ...................bootstrap=False, n_estimators=67; total time=   1.3s
# [CV] END ...................bootstrap=False, n_estimators=67; total time=   1.3s
# [CV] END ...................bootstrap=False, n_estimators=67; total time=   1.3s
# [CV] END ...................bootstrap=False, n_estimators=67; total time=   1.3s
# [CV] END ...................bootstrap=False, n_estimators=68; total time=   1.8s
# [CV] END ...................bootstrap=False, n_estimators=68; total time=   1.9s
# [CV] END ...................bootstrap=False, n_estimators=68; total time=   1.4s
# [CV] END ...................bootstrap=False, n_estimators=68; total time=   1.4s
# [CV] END ...................bootstrap=False, n_estimators=68; total time=   1.4s
# [CV] END ...................bootstrap=False, n_estimators=69; total time=   1.4s
# [CV] END ...................bootstrap=False, n_estimators=69; total time=   1.4s
# [CV] END ...................bootstrap=False, n_estimators=69; total time=   1.4s
# [CV] END ...................bootstrap=False, n_estimators=69; total time=   1.4s
# [CV] END ...................bootstrap=False, n_estimators=69; total time=   1.7s
# [CV] END ...................bootstrap=False, n_estimators=70; total time=   2.0s
# [CV] END ...................bootstrap=False, n_estimators=70; total time=   1.5s
# [CV] END ...................bootstrap=False, n_estimators=70; total time=   1.4s
# [CV] END ...................bootstrap=False, n_estimators=70; total time=   1.4s
# [CV] END ...................bootstrap=False, n_estimators=70; total time=   1.4s
# [CV] END ...................bootstrap=False, n_estimators=71; total time=   1.4s
# [CV] END ...................bootstrap=False, n_estimators=71; total time=   1.4s
# [CV] END ...................bootstrap=False, n_estimators=71; total time=   1.4s
# [CV] END ...................bootstrap=False, n_estimators=71; total time=   1.8s
# [CV] END ...................bootstrap=False, n_estimators=71; total time=   2.0s
# [CV] END ...................bootstrap=False, n_estimators=72; total time=   1.5s
# [CV] END ...................bootstrap=False, n_estimators=72; total time=   1.5s
# [CV] END ...................bootstrap=False, n_estimators=72; total time=   1.4s
# [CV] END ...................bootstrap=False, n_estimators=72; total time=   1.4s
# [CV] END ...................bootstrap=False, n_estimators=72; total time=   1.4s
# [CV] END ...................bootstrap=False, n_estimators=73; total time=   1.5s
# [CV] END ...................bootstrap=False, n_estimators=73; total time=   1.5s
# [CV] END ...................bootstrap=False, n_estimators=73; total time=   1.9s
# [CV] END ...................bootstrap=False, n_estimators=73; total time=   2.0s
# [CV] END ...................bootstrap=False, n_estimators=73; total time=   1.4s
# [CV] END ...................bootstrap=False, n_estimators=74; total time=   1.5s
# [CV] END ...................bootstrap=False, n_estimators=74; total time=   1.5s
# [CV] END ...................bootstrap=False, n_estimators=74; total time=   1.5s
# [CV] END ...................bootstrap=False, n_estimators=74; total time=   1.5s
# [CV] END ...................bootstrap=False, n_estimators=74; total time=   1.5s
# [CV] END ...................bootstrap=False, n_estimators=75; total time=   1.6s
# [CV] END ...................bootstrap=False, n_estimators=75; total time=   2.1s
# [CV] END ...................bootstrap=False, n_estimators=75; total time=   1.8s
# [CV] END ...................bootstrap=False, n_estimators=75; total time=   1.5s
# [CV] END ...................bootstrap=False, n_estimators=75; total time=   1.5s
# [CV] END ...................bootstrap=False, n_estimators=76; total time=   1.5s
# [CV] END ...................bootstrap=False, n_estimators=76; total time=   1.5s
# [CV] END ...................bootstrap=False, n_estimators=76; total time=   1.5s
# [CV] END ...................bootstrap=False, n_estimators=76; total time=   1.5s
# [CV] END ...................bootstrap=False, n_estimators=76; total time=   2.0s
# [CV] END ...................bootstrap=False, n_estimators=77; total time=   2.1s
# [CV] END ...................bootstrap=False, n_estimators=77; total time=   1.5s
# [CV] END ...................bootstrap=False, n_estimators=77; total time=   1.5s
# [CV] END ...................bootstrap=False, n_estimators=77; total time=   1.5s
# [CV] END ...................bootstrap=False, n_estimators=77; total time=   1.5s
# [CV] END ...................bootstrap=False, n_estimators=78; total time=   1.5s
# [CV] END ...................bootstrap=False, n_estimators=78; total time=   1.6s
# [CV] END ...................bootstrap=False, n_estimators=78; total time=   1.9s
# [CV] END ...................bootstrap=False, n_estimators=78; total time=   2.2s
# [CV] END ...................bootstrap=False, n_estimators=78; total time=   1.6s
# [CV] END ...................bootstrap=False, n_estimators=79; total time=   1.6s
# [CV] END ...................bootstrap=False, n_estimators=79; total time=   1.6s
# [CV] END ...................bootstrap=False, n_estimators=79; total time=   1.6s
# [CV] END ...................bootstrap=False, n_estimators=79; total time=   1.6s
# [CV] END ...................bootstrap=False, n_estimators=79; total time=   1.6s
# [CV] END ...................bootstrap=False, n_estimators=80; total time=   1.9s
# [CV] END ...................bootstrap=False, n_estimators=80; total time=   2.2s
# [CV] END ...................bootstrap=False, n_estimators=80; total time=   1.7s
# [CV] END ...................bootstrap=False, n_estimators=80; total time=   1.6s
# [CV] END ...................bootstrap=False, n_estimators=80; total time=   1.6s
# [CV] END ...................bootstrap=False, n_estimators=81; total time=   1.6s
# [CV] END ...................bootstrap=False, n_estimators=81; total time=   1.6s
# [CV] END ...................bootstrap=False, n_estimators=81; total time=   1.6s
# [CV] END ...................bootstrap=False, n_estimators=81; total time=   2.0s
# [CV] END ...................bootstrap=False, n_estimators=81; total time=   2.2s
# [CV] END ...................bootstrap=False, n_estimators=82; total time=   1.6s
# [CV] END ...................bootstrap=False, n_estimators=82; total time=   1.6s
# [CV] END ...................bootstrap=False, n_estimators=82; total time=   1.6s
# [CV] END ...................bootstrap=False, n_estimators=82; total time=   1.6s
# [CV] END ...................bootstrap=False, n_estimators=82; total time=   1.6s
# [CV] END ...................bootstrap=False, n_estimators=83; total time=   1.6s
# [CV] END ...................bootstrap=False, n_estimators=83; total time=   2.2s
# [CV] END ...................bootstrap=False, n_estimators=83; total time=   2.1s
# [CV] END ...................bootstrap=False, n_estimators=83; total time=   1.6s
# [CV] END ...................bootstrap=False, n_estimators=83; total time=   1.6s
# [CV] END ...................bootstrap=False, n_estimators=84; total time=   1.7s
# [CV] END ...................bootstrap=False, n_estimators=84; total time=   1.7s
# [CV] END ...................bootstrap=False, n_estimators=84; total time=   1.7s
# [CV] END ...................bootstrap=False, n_estimators=84; total time=   1.8s
# [CV] END ...................bootstrap=False, n_estimators=84; total time=   2.3s
# [CV] END ...................bootstrap=False, n_estimators=85; total time=   1.9s
# [CV] END ...................bootstrap=False, n_estimators=85; total time=   1.7s
# [CV] END ...................bootstrap=False, n_estimators=85; total time=   1.7s
# [CV] END ...................bootstrap=False, n_estimators=85; total time=   1.7s
# [CV] END ...................bootstrap=False, n_estimators=85; total time=   1.7s
# [CV] END ...................bootstrap=False, n_estimators=86; total time=   1.7s
# [CV] END ...................bootstrap=False, n_estimators=86; total time=   2.2s
# [CV] END ...................bootstrap=False, n_estimators=86; total time=   2.2s
# [CV] END ...................bootstrap=False, n_estimators=86; total time=   1.7s
# [CV] END ...................bootstrap=False, n_estimators=86; total time=   1.7s
# [CV] END ...................bootstrap=False, n_estimators=87; total time=   1.7s
# [CV] END ...................bootstrap=False, n_estimators=87; total time=   1.7s
# [CV] END ...................bootstrap=False, n_estimators=87; total time=   1.7s
# [CV] END ...................bootstrap=False, n_estimators=87; total time=   2.0s
# [CV] END ...................bootstrap=False, n_estimators=87; total time=   2.4s
# [CV] END ...................bootstrap=False, n_estimators=88; total time=   1.8s
# [CV] END ...................bootstrap=False, n_estimators=88; total time=   1.7s
# [CV] END ...................bootstrap=False, n_estimators=88; total time=   1.7s
# [CV] END ...................bootstrap=False, n_estimators=88; total time=   1.7s
# [CV] END ...................bootstrap=False, n_estimators=88; total time=   1.7s
# [CV] END ...................bootstrap=False, n_estimators=89; total time=   1.9s
# [CV] END ...................bootstrap=False, n_estimators=89; total time=   2.4s
# [CV] END ...................bootstrap=False, n_estimators=89; total time=   1.9s
# [CV] END ...................bootstrap=False, n_estimators=89; total time=   1.8s
# [CV] END ...................bootstrap=False, n_estimators=89; total time=   1.8s
# [CV] END ...................bootstrap=False, n_estimators=90; total time=   1.8s
# [CV] END ...................bootstrap=False, n_estimators=90; total time=   1.8s
# [CV] END ...................bootstrap=False, n_estimators=90; total time=   1.9s
# [CV] END ...................bootstrap=False, n_estimators=90; total time=   2.5s
# [CV] END ...................bootstrap=False, n_estimators=90; total time=   2.0s
# [CV] END ...................bootstrap=False, n_estimators=91; total time=   1.8s
# [CV] END ...................bootstrap=False, n_estimators=91; total time=   1.8s
# [CV] END ...................bootstrap=False, n_estimators=91; total time=   1.8s
# [CV] END ...................bootstrap=False, n_estimators=91; total time=   1.8s
# [CV] END ...................bootstrap=False, n_estimators=91; total time=   1.9s
# [CV] END ...................bootstrap=False, n_estimators=92; total time=   2.5s
# [CV] END ...................bootstrap=False, n_estimators=92; total time=   2.0s
# [CV] END ...................bootstrap=False, n_estimators=92; total time=   1.8s
# [CV] END ...................bootstrap=False, n_estimators=92; total time=   1.8s
# [CV] END ...................bootstrap=False, n_estimators=92; total time=   1.8s
# [CV] END ...................bootstrap=False, n_estimators=93; total time=   1.8s
# [CV] END ...................bootstrap=False, n_estimators=93; total time=   2.1s
# [CV] END ...................bootstrap=False, n_estimators=93; total time=   2.5s
# [CV] END ...................bootstrap=False, n_estimators=93; total time=   1.9s
# [CV] END ...................bootstrap=False, n_estimators=93; total time=   1.8s
# [CV] END ...................bootstrap=False, n_estimators=94; total time=   1.9s
# [CV] END ...................bootstrap=False, n_estimators=94; total time=   1.9s
# [CV] END ...................bootstrap=False, n_estimators=94; total time=   1.9s
# [CV] END ...................bootstrap=False, n_estimators=94; total time=   2.2s
# [CV] END ...................bootstrap=False, n_estimators=94; total time=   2.5s
# [CV] END ...................bootstrap=False, n_estimators=95; total time=   1.9s
# [CV] END ...................bootstrap=False, n_estimators=95; total time=   1.9s
# [CV] END ...................bootstrap=False, n_estimators=95; total time=   1.9s
# [CV] END ...................bootstrap=False, n_estimators=95; total time=   1.9s
# [CV] END ...................bootstrap=False, n_estimators=95; total time=   1.9s
# [CV] END ...................bootstrap=False, n_estimators=96; total time=   2.5s
# [CV] END ...................bootstrap=False, n_estimators=96; total time=   2.3s
# [CV] END ...................bootstrap=False, n_estimators=96; total time=   1.9s
# [CV] END ...................bootstrap=False, n_estimators=96; total time=   1.9s
# [CV] END ...................bootstrap=False, n_estimators=96; total time=   1.9s
# [CV] END ...................bootstrap=False, n_estimators=97; total time=   1.9s
# [CV] END ...................bootstrap=False, n_estimators=97; total time=   2.0s
# [CV] END ...................bootstrap=False, n_estimators=97; total time=   2.7s
# [CV] END ...................bootstrap=False, n_estimators=97; total time=   2.1s
# [CV] END ...................bootstrap=False, n_estimators=97; total time=   1.9s
# [CV] END ...................bootstrap=False, n_estimators=98; total time=   2.0s
# [CV] END ...................bootstrap=False, n_estimators=98; total time=   2.0s
# [CV] END ...................bootstrap=False, n_estimators=98; total time=   1.9s
# [CV] END ...................bootstrap=False, n_estimators=98; total time=   2.5s
# [CV] END ...................bootstrap=False, n_estimators=98; total time=   2.5s
# [CV] END ...................bootstrap=False, n_estimators=99; total time=   2.0s
# [CV] END ...................bootstrap=False, n_estimators=99; total time=   2.0s
# [CV] END ...................bootstrap=False, n_estimators=99; total time=   2.0s
# [CV] END ...................bootstrap=False, n_estimators=99; total time=   2.0s
# [CV] END ...................bootstrap=False, n_estimators=99; total time=   2.1s
# GridSearchCV(estimator=RandomForestRegressor(bootstrap=False, max_depth=5,
#                                              min_samples_leaf=3,
#                                              min_samples_split=5,
#                                              random_state=100),
#              param_grid={'bootstrap': [True, False],
#                          'n_estimators': range(50, 100)},
#              verbose=2)

# %%
grid_sch_rand.best_params_
# Out:
# {'bootstrap': True, 'n_estimators': 98}

# %%
## Building Random Forest model with best params
rand_for2=RandomForestRegressor(n_estimators=98,max_depth=5,min_samples_leaf=3,min_samples_split=5,random_state=100,bootstrap=True)

# %%
rand_model2=rand_for2.fit(x_train,y_train)

# %%
## RMSE, MAE, or R-squared of best params model
y_pred_rand2=rand_model2.predict(x_test)
rms_rand2=np.sqrt(mean_squared_error(y_test,y_pred_rand2))
print("RMSE:",rms_rand2)
mae_rand2=mean_absolute_error(y_test,y_pred_rand2)
print("MAE:",mae_rand2)
r2_rand2=r2_score(y_test,y_pred_rand2)
print("R2:",r2_rand2)
# Out:
# RMSE: 15.19848047117563
# MAE: 10.061879384415427
# R2: 0.990411791569749

# %%
from sklearn.metrics import mean_squared_error
train_pred=rand_model2.predict(x_train)
train_rmse = mean_squared_error(y_train, train_pred)
test_rmse = mean_squared_error(y_test, y_pred_rand2)

print(f"Train RMSE: {train_rmse}")
print(f"Test RMSE: {test_rmse}")
# Out:
# Train RMSE: 208.89054852010202
# Test RMSE: 230.99380863270702

# %%
from sklearn.model_selection import KFold, cross_val_score

# %%
X = features
Y = target

# K-Fold Cross-Validation
k = 5  # Number of folds
kf = KFold(n_splits=k, shuffle=True, random_state=42)

# Perform K-Fold Cross-Validation
fold_mse_rand2= []
for train_index, test_index in kf.split(X):
    # Use .iloc for positional indexing when X is a pandas DataFrame
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    Y_train, Y_test = Y.iloc[train_index], Y.iloc[test_index]

    # Train the model
    rand_model2.fit(X_train, Y_train)

    # Predict and evaluate
    y_pred_rand2= rand_model2.predict(X_test)
    mse_rand2 = mean_squared_error(Y_test, y_pred_rand2)
    fold_mse_rand2.append(mse_rand2)

# the Mean Squared Error for each fold and the average
print("Fold MSEs:", fold_mse_rand2)
print("Average MSE:", np.mean(fold_mse_rand2))

train_rmse = mean_squared_error(y_train, train_pred)
print(f"Train RMSE: {train_rmse}")
# Out:
# Fold MSEs: [231.5884817452911, 206.70369910534242, 246.4387435938575, 246.32689612121183, 265.66632937802274]
# Average MSE: 239.3448299887451
# Train RMSE: 208.89054852010202

# %%
## Overfitting Check: If the training RMSE is much smaller than the test RMSE, the model may be overfitting.
## The RMSE of train and testing data is almost equal

# %% [markdown]
# #### Gradient Boosting Regression

# %%
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import RandomizedSearchCV

# %%
gb_model = GradientBoostingRegressor(n_estimators=50,learning_rate=0.01,max_depth=5)

# %%
gb_model.fit(x_train,y_train)
# Out:
# GradientBoostingRegressor(learning_rate=0.01, max_depth=5, n_estimators=50)

# %%
## RMSE, MAE, or R-squared
y_pred_gb=gb_model.predict(x_test)
rms_gb=np.sqrt(mean_squared_error(y_test,y_pred_gb))
print("RMSE:",rms_gb)
mae_gb=mean_absolute_error(y_test,y_pred_gb)
print("MAE:",mae_gb)
r2_gb=r2_score(y_test,y_pred_gb)
print("R2:",r2_gb)
# Out:
# RMSE: 94.63301581926024
# MAE: 77.14017585410524
# R2: 0.6282743855725117

# %%
gb_param_grid = {'n_estimators': [50,100,150,200,250,300],'learning_rate': [0.01, 0.1, 0.2],'max_depth': [3, 5, 7]}
gb_random_search = RandomizedSearchCV(estimator=gb_model, param_distributions=gb_param_grid,n_iter=10, cv=3, verbose=2)

# %%
#Finding the best parameters using Random search
gb_random_search.fit(x_train, y_train)
# Out:
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=150; total time=   1.7s
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=150; total time=   1.7s
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=150; total time=   1.7s
# [CV] END ...learning_rate=0.1, max_depth=7, n_estimators=300; total time=   8.4s
# [CV] END ...learning_rate=0.1, max_depth=7, n_estimators=300; total time=   7.2s
# [CV] END ...learning_rate=0.1, max_depth=7, n_estimators=300; total time=   8.2s
# [CV] END ...learning_rate=0.2, max_depth=7, n_estimators=200; total time=   4.9s
# [CV] END ...learning_rate=0.2, max_depth=7, n_estimators=200; total time=   5.8s
# [CV] END ...learning_rate=0.2, max_depth=7, n_estimators=200; total time=   4.9s
# [CV] END ...learning_rate=0.2, max_depth=7, n_estimators=250; total time=   7.0s
# [CV] END ...learning_rate=0.2, max_depth=7, n_estimators=250; total time=   6.0s
# [CV] END ...learning_rate=0.2, max_depth=7, n_estimators=250; total time=   6.8s
# [CV] END ...learning_rate=0.01, max_depth=3, n_estimators=50; total time=   0.8s
# [CV] END ...learning_rate=0.01, max_depth=3, n_estimators=50; total time=   0.6s
# [CV] END ...learning_rate=0.01, max_depth=3, n_estimators=50; total time=   0.6s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=250; total time=   2.7s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=250; total time=   2.7s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=250; total time=   2.8s
# [CV] END ...learning_rate=0.1, max_depth=7, n_estimators=100; total time=   3.2s
# [CV] END ...learning_rate=0.1, max_depth=7, n_estimators=100; total time=   2.8s
# [CV] END ...learning_rate=0.1, max_depth=7, n_estimators=100; total time=   2.5s
# [CV] END ...learning_rate=0.1, max_depth=5, n_estimators=300; total time=   5.2s
# [CV] END ...learning_rate=0.1, max_depth=5, n_estimators=300; total time=   6.3s
# [CV] END ...learning_rate=0.1, max_depth=5, n_estimators=300; total time=   5.2s
# [CV] END ...learning_rate=0.2, max_depth=5, n_estimators=200; total time=   3.8s
# [CV] END ...learning_rate=0.2, max_depth=5, n_estimators=200; total time=   4.2s
# [CV] END ...learning_rate=0.2, max_depth=5, n_estimators=200; total time=   3.5s
# [CV] END ...learning_rate=0.1, max_depth=7, n_estimators=150; total time=   3.7s
# [CV] END ...learning_rate=0.1, max_depth=7, n_estimators=150; total time=   4.5s
# [CV] END ...learning_rate=0.1, max_depth=7, n_estimators=150; total time=   3.6s
# RandomizedSearchCV(cv=3,
#                    estimator=GradientBoostingRegressor(learning_rate=0.01,
#                                                        max_depth=5,
#                                                        n_estimators=50),
#                    param_distributions={'learning_rate': [0.01, 0.1, 0.2],
#                                         'max_depth': [3, 5, 7],
#                                         'n_estimators': [50, 100, 150, 200, 250,
#                                                          300]},
#                    verbose=2)

# %%
gb_best_params = gb_random_search.best_params_
gb_best_score = gb_random_search.best_score_
print('gb_best_params=',gb_best_params)
print('gb_best_score=',gb_best_score)
# Out:
# gb_best_params= {'n_estimators': 300, 'max_depth': 7, 'learning_rate': 0.1}
# gb_best_score= 0.9997964080939487

# %%
## Building the model with best parameters
gb_model2 = GradientBoostingRegressor(n_estimators=50,learning_rate=0.01,max_depth=5)
gb_model2.fit(x_train,y_train)
# Out:
# GradientBoostingRegressor(learning_rate=0.01, max_depth=5, n_estimators=50)

# %%
## RMSE, MAE, R-squared value of best params model
y_pred_gb2=gb_model2.predict(x_test)
rms_gb2=np.sqrt(mean_squared_error(y_test,y_pred_gb2))
print("RMSE:",rms_gb2)
mae_gb2=mean_absolute_error(y_test,y_pred_gb2)
print("MAE:",mae_gb2)
r2_gb2=r2_score(y_test,y_pred_gb2)
print("R2:",r2_gb2)
# Out:
# RMSE: 94.63301581926024
# MAE: 77.14017585410524
# R2: 0.6282743855725117

# %%
train_pred_gb2=gb_model2.predict(x_train)
train_rmse_gb2= mean_squared_error(y_train, train_pred_gb2)
test_rmse_gb2= mean_squared_error(y_test, y_pred_gb2)

print(f"Train RMSE: {train_rmse_gb2}")
print(f"Test RMSE: {test_rmse_gb2}")
# Out:
# Train RMSE: 8944.809575673815
# Test RMSE: 8955.40768304836

# %%
## Overfitting Check: If the training RMSE is much smaller than the test RMSE, the model may be overfitting.
## The RMSE of train and testing data is almost equal

# %% [markdown]
# # **6.Model Evaluation:**

# %% [markdown]
# ### Compare the performance of different models to select the best one.

# %% [markdown]
# Based on the performance of models like Random forest Regressor , Decision Tree and Gradient Boosting Regressor:
#
# -> Random Forest Model yields the best results ,99% of the variability in the target variable is explained by the model

# %% [markdown]
# # **7.Model Deployment:**

# %%
# !pip install streamlit
# Out:
# Collecting streamlit
#   Downloading streamlit-1.41.1-py2.py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: altair<6,>=4.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<6,>=4.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (5.5.0)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (8.1.8)
# Requirement already satisfied: numpy<3,>=1.23 in /usr/local/lib/python3.11/dist-packages (from streamlit) (1.26.4)
# Requirement already satisfied: packaging<25,>=20 in /usr/local/lib/python3.11/dist-packages (from streamlit) (24.2)
# Requirement already satisfied: pandas<3,>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (2.2.2)
# Requirement already satisfied: pillow<12,>=7.1.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (11.1.0)
# Requirement already satisfied: protobuf<6,>=3.20 in /usr/local/lib/python3.11/dist-packages (from streamlit) (4.25.5)
# Requirement already satisfied: pyarrow>=7.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (17.0.0)
# Requirement already satisfied: requests<3,>=2.27 in /usr/local/lib/python3.11/dist-packages (from streamlit) (2.32.3)
# Requirement already satisfied: rich<14,>=10.14.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (13.9.4)
# Requirement already satisfied: tenacity<10,>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (9.0.0)
# Requirement already satisfied: toml<2,>=0.10.1 in /usr/local/lib/python3.11/dist-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (4.12.2)
# Collecting watchdog<7,>=2.1.5 (from streamlit)
#   Downloading watchdog-6.0.0-py3-none-manylinux2014_x86_64.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 1.6 MB/s eta 0:00:00
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /usr/local/lib/python3.11/dist-packages (from streamlit) (3.1.44)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit)
#   Downloading pydeck-0.9.1-py2.py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: tornado<7,>=6.0.3 in /usr/local/lib/python3.11/dist-packages (from streamlit) (6.3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from altair<6,>=4.0->streamlit) (3.1.5)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.11/dist-packages (from altair<6,>=4.0->streamlit) (4.23.0)
# Requirement already satisfied: narwhals>=1.14.2 in /usr/local/lib/python3.11/dist-packages (from altair<6,>=4.0->streamlit) (1.21.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas<3,>=1.4.0->streamlit) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas<3,>=1.4.0->streamlit) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas<3,>=1.4.0->streamlit) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27->streamlit) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27->streamlit) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27->streamlit) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27->streamlit) (2024.12.14)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich<14,>=10.14.0->streamlit) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich<14,>=10.14.0->streamlit) (2.18.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->altair<6,>=4.0->streamlit) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.22.3)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)
# Downloading streamlit-1.41.1-py2.py3-none-any.whl (9.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 52.7 MB/s eta 0:00:00
# Downloading pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 54.8 MB/s eta 0:00:00
# Downloading watchdog-6.0.0-py3-none-manylinux2014_x86_64.whl (79 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 5.1 MB/s eta 0:00:00
# Installing collected packages: watchdog, pydeck, streamlit
# Successfully installed pydeck-0.9.1 streamlit-1.41.1 watchdog-6.0.0

# %%
import pickle
import streamlit as st

# %%
file='model.pkl'

# %%
pickle.dump(rand_model2,open('file','wb'))
